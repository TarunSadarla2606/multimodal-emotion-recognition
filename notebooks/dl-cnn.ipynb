# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("zaber666/meld-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/meld-dataset

# %%
import os
import cv2
import pandas as pd
from tqdm import tqdm

# Config for each split
SPLITS = {
    'train': {
        'csv': '/kaggle/input/meld-dataset/MELD-RAW/MELD.Raw/train/train_sent_emo.csv',
        'video_dir': '/kaggle/input/meld-dataset/MELD-RAW/MELD.Raw/train/train_splits',
        'output_dir': '/kaggle/working/frames/train'
    },
    'val': {
        'csv': '/kaggle/input/meld-dataset/MELD-RAW/MELD.Raw/dev_sent_emo.csv',
        'video_dir': '/kaggle/input/meld-dataset/MELD-RAW/MELD.Raw/dev/dev_splits_complete',
        'output_dir': '/kaggle/working/frames/val'
    },
    'test': {
        'csv': '/kaggle/input/meld-dataset/MELD-RAW/MELD.Raw/test_sent_emo.csv',
        'video_dir': '/kaggle/input/meld-dataset/MELD-RAW/MELD.Raw/test/output_repeated_splits_test',
        'output_dir': '/kaggle/working/frames/test'
    }
}

FRAME_INTERVAL = 3  # seconds

# Main loop
for split_name, paths in SPLITS.items():
    print(f"\n[INFO] Extracting frames for split: {split_name}")
    
    df = pd.read_csv(paths['csv'])
    os.makedirs(paths['output_dir'], exist_ok=True)
    available_videos = os.listdir(paths['video_dir'])

    for idx, row in tqdm(df.iterrows(), total=len(df)):
        dia_id = row['Dialogue_ID']
        utt_id = row['Utterance_ID']
        expected_name = f'dia{dia_id}_utt{utt_id}.mp4'

        # Match video file name
        if split_name == 'test':
            # Match by checking if filename ends with expected pattern
            matched_files = [f for f in available_videos if f.endswith(expected_name)]
            if not matched_files:
                continue
            video_name = matched_files[0]  # use first match
        else:
            if expected_name not in available_videos:
                continue
            video_name = expected_name

        video_path = os.path.join(paths['video_dir'], video_name)
        save_dir = os.path.join(paths['output_dir'], f"{dia_id}_{utt_id}")
        os.makedirs(save_dir, exist_ok=True)

        cap = cv2.VideoCapture(video_path)
        fps = cap.get(cv2.CAP_PROP_FPS)
        frame_interval = int(fps * FRAME_INTERVAL) if fps and fps > 0 else 30  # fallback in case fps = 0
        frame_count = 0
        save_count = 0

        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break
            if frame_count % frame_interval == 0:
                frame_resized = cv2.resize(frame, (224, 224))
                frame_filename = f"frame_{save_count:03d}.jpg"
                cv2.imwrite(os.path.join(save_dir, frame_filename), frame_resized)
                save_count += 1
            frame_count += 1

        cap.release()

    print(f"[INFO] Done with {split_name} — processed {len(df)} entries (some skipped if no match).")
# Out:
# [INFO] Extracting frames for split: train
#  12%|█▏        | 1164/9989 [03:17<31:14,  4.71it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb0554c0] moov atom not found
# 100%|██████████| 9989/9989 [30:29<00:00,  5.46it/s]
# [INFO] Done with train — processed 9989 entries (some skipped if no match).
#
# [INFO] Extracting frames for split: val
# 100%|██████████| 1109/1109 [03:17<00:00,  5.60it/s]
# [INFO] Done with val — processed 1109 entries (some skipped if no match).
#
# [INFO] Extracting frames for split: test
#   0%|          | 6/2610 [00:01<06:30,  6.67it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#   0%|          | 8/2610 [00:01<05:22,  8.07it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#   0%|          | 11/2610 [00:01<04:04, 10.62it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#   1%|          | 14/2610 [00:01<03:04, 14.04it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#   1%|          | 21/2610 [00:02<03:44, 11.52it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#   1%|          | 24/2610 [00:02<02:55, 14.76it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#   1%|          | 26/2610 [00:02<03:09, 13.64it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#   1%|          | 32/2610 [00:02<04:01, 10.69it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#   1%|▏         | 34/2610 [00:03<03:33, 12.06it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#   1%|▏         | 36/2610 [00:03<04:34,  9.38it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#   1%|▏         | 38/2610 [00:03<04:09, 10.30it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb04d2c0] moov atom not found
#   2%|▏         | 43/2610 [00:03<03:58, 10.78it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#   2%|▏         | 45/2610 [00:04<03:34, 11.96it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#   2%|▏         | 47/2610 [00:04<04:01, 10.61it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#   2%|▏         | 49/2610 [00:04<04:06, 10.39it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#   2%|▏         | 53/2610 [00:04<03:13, 13.24it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#   2%|▏         | 55/2610 [00:04<03:23, 12.57it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#   2%|▏         | 63/2610 [00:05<02:52, 14.78it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#   3%|▎         | 68/2610 [00:06<04:42,  9.00it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#   3%|▎         | 70/2610 [00:06<04:19,  9.79it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#   3%|▎         | 73/2610 [00:06<04:01, 10.52it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#   3%|▎         | 75/2610 [00:06<04:09, 10.18it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#   3%|▎         | 77/2610 [00:07<05:52,  7.18it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#   3%|▎         | 81/2610 [00:07<04:58,  8.47it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#   3%|▎         | 85/2610 [00:07<03:47, 11.10it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#   3%|▎         | 87/2610 [00:07<03:33, 11.84it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#   3%|▎         | 91/2610 [00:08<04:44,  8.86it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#   4%|▎         | 93/2610 [00:08<05:00,  8.36it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#   4%|▍         | 99/2610 [00:09<04:06, 10.17it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#   4%|▍         | 105/2610 [00:09<02:49, 14.82it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#   4%|▍         | 108/2610 [00:09<02:45, 15.13it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#   4%|▍         | 113/2610 [00:09<02:35, 16.08it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#   4%|▍         | 116/2610 [00:10<02:30, 16.56it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#   5%|▍         | 118/2610 [00:10<02:40, 15.55it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#   5%|▍         | 127/2610 [00:11<05:24,  7.66it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#   5%|▍         | 129/2610 [00:11<04:27,  9.27it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#   5%|▌         | 132/2610 [00:12<03:15, 12.66it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#   5%|▌         | 137/2610 [00:12<02:25, 17.04it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad40] moov atom not found
#   5%|▌         | 139/2610 [00:12<02:30, 16.41it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#   6%|▌         | 147/2610 [00:13<03:28, 11.83it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#   6%|▌         | 149/2610 [00:13<03:36, 11.36it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#   6%|▌         | 156/2610 [00:14<06:16,  6.51it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#   6%|▋         | 166/2610 [00:15<05:56,  6.86it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#   7%|▋         | 173/2610 [00:16<05:44,  7.06it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb057280] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb057280] moov atom not found
#   7%|▋         | 177/2610 [00:17<05:52,  6.91it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#   7%|▋         | 179/2610 [00:17<05:10,  7.83it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#   7%|▋         | 182/2610 [00:17<05:09,  7.85it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb4d3dc0] moov atom not found
#   7%|▋         | 184/2610 [00:18<06:00,  6.72it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#   7%|▋         | 190/2610 [00:18<05:59,  6.73it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad40] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#   7%|▋         | 194/2610 [00:19<04:07,  9.75it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#   8%|▊         | 196/2610 [00:19<03:40, 10.95it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#   8%|▊         | 198/2610 [00:19<04:34,  8.80it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#   8%|▊         | 203/2610 [00:20<06:41,  5.99it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#   8%|▊         | 205/2610 [00:20<05:45,  6.95it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#   8%|▊         | 207/2610 [00:20<05:03,  7.92it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#   8%|▊         | 209/2610 [00:20<04:26,  9.00it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#   8%|▊         | 211/2610 [00:21<04:02,  9.89it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#   8%|▊         | 217/2610 [00:21<04:25,  9.03it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#   8%|▊         | 219/2610 [00:21<04:14,  9.41it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#   9%|▊         | 222/2610 [00:22<03:40, 10.84it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#   9%|▊         | 228/2610 [00:22<04:48,  8.26it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#   9%|▉         | 232/2610 [00:23<04:34,  8.66it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#   9%|▉         | 237/2610 [00:23<03:38, 10.88it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#   9%|▉         | 239/2610 [00:24<04:21,  9.06it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#   9%|▉         | 241/2610 [00:24<03:41, 10.72it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#   9%|▉         | 245/2610 [00:24<03:49, 10.30it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  10%|▉         | 248/2610 [00:24<03:14, 12.17it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  10%|▉         | 257/2610 [00:25<04:21,  8.99it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  10%|█         | 261/2610 [00:25<02:55, 13.41it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  10%|█         | 263/2610 [00:26<03:18, 11.84it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  10%|█         | 269/2610 [00:27<06:18,  6.18it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  11%|█         | 276/2610 [00:28<05:52,  6.62it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  11%|█         | 278/2610 [00:28<05:04,  7.67it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  11%|█         | 282/2610 [00:29<06:37,  5.86it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  11%|█         | 285/2610 [00:29<07:58,  4.86it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  11%|█         | 289/2610 [00:30<08:32,  4.52it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  11%|█▏        | 298/2610 [00:32<08:04,  4.77it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  11%|█▏        | 300/2610 [00:32<08:26,  4.56it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  12%|█▏        | 304/2610 [00:32<04:32,  8.45it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  12%|█▏        | 310/2610 [00:33<06:19,  6.07it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  12%|█▏        | 314/2610 [00:34<06:46,  5.65it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb00eb00] moov atom not found
#  12%|█▏        | 316/2610 [00:34<06:06,  6.26it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  12%|█▏        | 318/2610 [00:35<05:21,  7.12it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  12%|█▏        | 322/2610 [00:35<04:42,  8.11it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  13%|█▎        | 329/2610 [00:36<06:01,  6.31it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  13%|█▎        | 334/2610 [00:37<03:50,  9.86it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  13%|█▎        | 337/2610 [00:37<05:15,  7.20it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  13%|█▎        | 340/2610 [00:38<06:11,  6.11it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  13%|█▎        | 346/2610 [00:38<03:23, 11.14it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad80] moov atom not found
#  13%|█▎        | 350/2610 [00:54<1:14:42,  1.98s/it][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  14%|█▎        | 354/2610 [00:54<44:49,  1.19s/it]  [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  14%|█▎        | 358/2610 [00:55<28:25,  1.32it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  14%|█▍        | 363/2610 [00:55<17:13,  2.17it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  14%|█▍        | 370/2610 [00:56<08:25,  4.43it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad40] moov atom not found
#  14%|█▍        | 374/2610 [00:56<06:17,  5.92it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  15%|█▍        | 383/2610 [00:57<03:39, 10.15it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  15%|█▍        | 387/2610 [00:57<03:44,  9.88it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  15%|█▍        | 389/2610 [00:57<03:52,  9.57it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  15%|█▌        | 394/2610 [00:57<03:09, 11.69it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  15%|█▌        | 396/2610 [00:58<03:18, 11.13it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  15%|█▌        | 398/2610 [00:58<03:40, 10.05it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  15%|█▌        | 400/2610 [00:58<03:09, 11.67it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb057280] moov atom not found
#  15%|█▌        | 402/2610 [00:58<03:18, 11.10it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad40] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  16%|█▌        | 410/2610 [00:59<04:26,  8.25it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  16%|█▌        | 412/2610 [00:59<04:08,  8.86it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  16%|█▌        | 414/2610 [01:00<07:49,  4.68it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  16%|█▌        | 418/2610 [01:01<05:16,  6.92it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  16%|█▌        | 420/2610 [01:01<04:35,  7.96it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  16%|█▌        | 424/2610 [01:01<03:39,  9.98it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  16%|█▋        | 428/2610 [01:01<02:29, 14.64it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  17%|█▋        | 437/2610 [01:02<02:35, 13.93it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  17%|█▋        | 439/2610 [01:02<02:58, 12.17it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  17%|█▋        | 441/2610 [01:02<02:59, 12.11it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  17%|█▋        | 445/2610 [01:02<02:54, 12.40it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  17%|█▋        | 449/2610 [01:03<03:49,  9.41it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  17%|█▋        | 455/2610 [01:04<04:39,  7.72it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  18%|█▊        | 459/2610 [01:04<03:50,  9.35it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  18%|█▊        | 461/2610 [01:04<04:00,  8.93it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  18%|█▊        | 465/2610 [01:05<03:22, 10.62it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  18%|█▊        | 467/2610 [01:05<03:06, 11.48it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  18%|█▊        | 471/2610 [01:05<03:44,  9.53it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  18%|█▊        | 473/2610 [01:06<05:37,  6.34it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  18%|█▊        | 475/2610 [01:06<04:42,  7.57it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  18%|█▊        | 477/2610 [01:06<04:17,  8.29it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb00eb00] moov atom not found
#  18%|█▊        | 479/2610 [01:06<04:22,  8.13it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  19%|█▊        | 484/2610 [01:07<05:25,  6.52it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  19%|█▊        | 486/2610 [01:08<04:37,  7.66it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  19%|█▉        | 492/2610 [01:08<03:07, 11.28it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad40] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad40] moov atom not found
#  19%|█▉        | 496/2610 [01:08<02:24, 14.62it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  19%|█▉        | 502/2610 [01:09<04:27,  7.87it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  19%|█▉        | 504/2610 [01:09<04:04,  8.61it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  19%|█▉        | 507/2610 [01:09<03:06, 11.30it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  20%|█▉        | 509/2610 [01:09<03:10, 11.03it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  20%|█▉        | 512/2610 [01:10<02:47, 12.54it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  20%|█▉        | 518/2610 [01:10<01:55, 18.13it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb104a80] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb104a80] moov atom not found
#  20%|█▉        | 521/2610 [01:10<01:47, 19.43it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  20%|██        | 524/2610 [01:10<01:55, 18.08it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  20%|██        | 532/2610 [01:11<03:58,  8.72it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb4c76c0] moov atom not found
#  20%|██        | 535/2610 [01:12<06:07,  5.65it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  21%|██        | 541/2610 [01:13<04:19,  7.98it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  21%|██        | 546/2610 [01:13<03:40,  9.37it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  21%|██        | 549/2610 [01:13<03:43,  9.24it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  21%|██        | 551/2610 [01:13<03:27,  9.92it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb5bf200] moov atom not found
#  21%|██        | 553/2610 [01:14<04:32,  7.56it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  21%|██▏       | 557/2610 [01:14<03:50,  8.91it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  21%|██▏       | 559/2610 [01:14<03:22, 10.12it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  21%|██▏       | 561/2610 [01:15<03:07, 10.94it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  22%|██▏       | 563/2610 [01:15<02:43, 12.52it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  22%|██▏       | 565/2610 [01:15<03:22, 10.09it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad80] moov atom not found
#  22%|██▏       | 567/2610 [01:15<02:55, 11.65it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  22%|██▏       | 569/2610 [01:15<03:06, 10.94it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  22%|██▏       | 571/2610 [01:15<02:54, 11.67it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  22%|██▏       | 577/2610 [01:16<01:50, 18.47it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  22%|██▏       | 580/2610 [01:16<01:45, 19.32it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  22%|██▏       | 583/2610 [01:16<02:50, 11.89it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  22%|██▏       | 587/2610 [01:17<03:07, 10.76it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  23%|██▎       | 589/2610 [01:17<02:48, 12.03it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  23%|██▎       | 591/2610 [01:17<03:05, 10.86it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  23%|██▎       | 598/2610 [01:18<03:22,  9.91it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  23%|██▎       | 600/2610 [01:18<03:03, 10.98it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  23%|██▎       | 606/2610 [01:18<03:26,  9.69it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  23%|██▎       | 610/2610 [01:19<04:51,  6.86it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  23%|██▎       | 612/2610 [01:19<04:03,  8.19it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  24%|██▎       | 618/2610 [01:20<04:23,  7.55it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  24%|██▍       | 621/2610 [01:20<03:30,  9.47it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  24%|██▍       | 626/2610 [01:20<02:05, 15.77it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  24%|██▍       | 630/2610 [01:21<02:58, 11.07it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  24%|██▍       | 634/2610 [01:21<02:38, 12.47it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  25%|██▍       | 640/2610 [01:22<03:06, 10.56it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  25%|██▍       | 642/2610 [01:22<03:12, 10.25it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  25%|██▍       | 644/2610 [01:22<03:46,  8.66it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  25%|██▍       | 647/2610 [01:23<04:14,  7.72it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  25%|██▍       | 651/2610 [01:23<02:42, 12.05it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  25%|██▌       | 655/2610 [01:24<04:06,  7.92it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  25%|██▌       | 662/2610 [01:25<05:28,  5.94it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  25%|██▌       | 664/2610 [01:26<06:11,  5.23it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  26%|██▌       | 667/2610 [01:26<05:22,  6.02it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb057280] moov atom not found
#  26%|██▌       | 669/2610 [01:26<04:11,  7.73it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  26%|██▌       | 672/2610 [01:26<03:35,  8.98it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb057280] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb057280] moov atom not found
#  26%|██▌       | 675/2610 [01:27<03:16,  9.85it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  26%|██▌       | 677/2610 [01:27<03:31,  9.12it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  26%|██▌       | 680/2610 [01:27<03:52,  8.32it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb057280] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb057280] moov atom not found
#  26%|██▌       | 683/2610 [01:27<02:49, 11.34it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  26%|██▋       | 690/2610 [01:28<03:50,  8.34it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  27%|██▋       | 692/2610 [01:28<03:17,  9.71it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  27%|██▋       | 698/2610 [01:29<04:35,  6.95it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb0a9100] moov atom not found
#  27%|██▋       | 705/2610 [01:31<05:34,  5.70it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  27%|██▋       | 707/2610 [01:31<04:16,  7.41it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  27%|██▋       | 710/2610 [01:31<04:08,  7.65it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb057280] moov atom not found
#  27%|██▋       | 712/2610 [01:31<03:40,  8.60it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  27%|██▋       | 715/2610 [01:31<02:36, 12.09it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  28%|██▊       | 722/2610 [01:32<02:27, 12.81it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  28%|██▊       | 732/2610 [01:33<03:50,  8.15it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  28%|██▊       | 734/2610 [01:33<04:01,  7.76it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  28%|██▊       | 737/2610 [01:34<04:28,  6.98it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  28%|██▊       | 740/2610 [01:34<03:34,  8.71it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  28%|██▊       | 743/2610 [01:34<03:11,  9.73it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  29%|██▊       | 750/2610 [01:35<02:02, 15.18it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  29%|██▉       | 752/2610 [01:35<02:28, 12.51it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  29%|██▉       | 763/2610 [01:37<04:13,  7.28it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  29%|██▉       | 767/2610 [01:37<04:32,  6.77it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  30%|██▉       | 771/2610 [01:38<05:48,  5.27it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  30%|██▉       | 776/2610 [01:39<06:08,  4.97it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  30%|██▉       | 782/2610 [01:40<05:48,  5.25it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb057280] moov atom not found
#  30%|███       | 784/2610 [01:40<04:40,  6.52it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  30%|███       | 790/2610 [01:41<04:11,  7.24it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  30%|███       | 795/2610 [01:41<03:00, 10.06it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  31%|███       | 797/2610 [01:41<02:50, 10.62it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  31%|███       | 799/2610 [01:42<03:04,  9.84it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad40] moov atom not found
#  31%|███       | 802/2610 [01:42<02:21, 12.78it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  31%|███       | 804/2610 [01:42<02:16, 13.24it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  31%|███       | 806/2610 [01:42<02:19, 12.98it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  31%|███       | 808/2610 [01:42<02:57, 10.17it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  32%|███▏      | 823/2610 [01:44<03:12,  9.26it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  32%|███▏      | 826/2610 [01:45<02:16, 13.10it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  32%|███▏      | 828/2610 [01:45<02:07, 14.01it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  32%|███▏      | 836/2610 [01:46<03:33,  8.31it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  32%|███▏      | 842/2610 [01:46<03:07,  9.45it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  32%|███▏      | 845/2610 [01:46<02:36, 11.28it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  33%|███▎      | 849/2610 [01:47<03:16,  8.97it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  33%|███▎      | 851/2610 [01:47<03:16,  8.95it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  33%|███▎      | 853/2610 [01:47<03:06,  9.43it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  33%|███▎      | 857/2610 [01:48<03:01,  9.67it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  33%|███▎      | 864/2610 [01:49<05:00,  5.82it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  33%|███▎      | 869/2610 [01:49<03:10,  9.14it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  33%|███▎      | 873/2610 [01:50<02:44, 10.56it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  34%|███▎      | 875/2610 [01:50<02:29, 11.62it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  34%|███▎      | 877/2610 [01:50<02:18, 12.51it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  34%|███▎      | 879/2610 [01:50<02:06, 13.74it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb057280] moov atom not found
#  34%|███▍      | 881/2610 [01:50<02:43, 10.56it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  34%|███▍      | 883/2610 [01:50<02:32, 11.29it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  34%|███▍      | 886/2610 [01:51<02:20, 12.27it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  34%|███▍      | 888/2610 [01:51<02:12, 13.01it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  34%|███▍      | 898/2610 [01:52<03:55,  7.26it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  34%|███▍      | 900/2610 [01:52<03:35,  7.92it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  35%|███▍      | 903/2610 [01:52<02:47, 10.20it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb5bdd40] moov atom not found
#  35%|███▍      | 909/2610 [01:53<03:37,  7.82it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  35%|███▍      | 911/2610 [01:53<03:00,  9.44it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  35%|███▍      | 913/2610 [01:53<02:43, 10.38it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  35%|███▌      | 921/2610 [01:54<02:47, 10.07it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  35%|███▌      | 924/2610 [01:55<04:00,  7.01it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  36%|███▌      | 928/2610 [01:55<04:00,  7.00it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  36%|███▌      | 930/2610 [01:56<04:23,  6.38it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  36%|███▌      | 933/2610 [01:56<03:04,  9.07it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad80] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  36%|███▌      | 938/2610 [01:56<02:38, 10.58it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  36%|███▌      | 941/2610 [01:56<02:10, 12.80it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  36%|███▌      | 943/2610 [01:57<02:02, 13.58it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  36%|███▌      | 945/2610 [01:57<01:52, 14.81it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  36%|███▋      | 949/2610 [01:57<01:41, 16.39it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  36%|███▋      | 951/2610 [01:57<02:22, 11.65it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  37%|███▋      | 953/2610 [01:58<04:09,  6.65it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  37%|███▋      | 955/2610 [01:58<04:17,  6.44it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  37%|███▋      | 958/2610 [01:59<04:24,  6.24it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  37%|███▋      | 961/2610 [01:59<03:36,  7.63it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  37%|███▋      | 964/2610 [01:59<02:52,  9.54it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  37%|███▋      | 968/2610 [02:00<03:05,  8.86it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  37%|███▋      | 970/2610 [02:00<03:35,  7.60it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  37%|███▋      | 972/2610 [02:00<04:17,  6.36it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  37%|███▋      | 975/2610 [02:01<03:38,  7.50it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  38%|███▊      | 981/2610 [02:01<03:30,  7.74it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  38%|███▊      | 985/2610 [02:02<03:26,  7.85it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  38%|███▊      | 990/2610 [02:02<02:46,  9.71it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  38%|███▊      | 996/2610 [02:03<02:52,  9.38it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  38%|███▊      | 1000/2610 [02:03<02:42,  9.89it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  38%|███▊      | 1003/2610 [02:04<03:08,  8.51it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  39%|███▊      | 1008/2610 [02:04<03:07,  8.54it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  39%|███▊      | 1011/2610 [02:05<03:12,  8.32it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  39%|███▉      | 1015/2610 [02:05<02:43,  9.74it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  39%|███▉      | 1017/2610 [02:05<02:23, 11.11it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  39%|███▉      | 1019/2610 [02:05<02:12, 12.05it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  39%|███▉      | 1023/2610 [02:06<02:19, 11.35it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  39%|███▉      | 1025/2610 [02:06<02:13, 11.91it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  39%|███▉      | 1030/2610 [02:06<03:01,  8.73it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  40%|███▉      | 1033/2610 [02:07<04:36,  5.71it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  40%|███▉      | 1035/2610 [02:07<03:45,  6.99it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  40%|███▉      | 1038/2610 [02:08<02:55,  8.98it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  40%|███▉      | 1041/2610 [02:08<04:48,  5.43it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  40%|████      | 1045/2610 [02:09<04:08,  6.29it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  40%|████      | 1054/2610 [02:10<02:43,  9.54it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad40] moov atom not found
#  40%|████      | 1056/2610 [02:10<02:34, 10.06it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  41%|████      | 1059/2610 [02:10<02:14, 11.52it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  41%|████      | 1061/2610 [02:10<03:03,  8.42it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  41%|████      | 1063/2610 [02:11<02:55,  8.82it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  41%|████      | 1069/2610 [02:11<03:10,  8.08it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  41%|████      | 1071/2610 [02:12<03:43,  6.89it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  41%|████▏     | 1079/2610 [02:13<03:15,  7.83it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  41%|████▏     | 1082/2610 [02:13<02:32,  9.99it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  42%|████▏     | 1087/2610 [02:13<02:36,  9.74it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad40] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  42%|████▏     | 1090/2610 [02:14<03:06,  8.13it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  42%|████▏     | 1096/2610 [02:15<04:06,  6.14it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  42%|████▏     | 1101/2610 [02:15<02:54,  8.63it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  42%|████▏     | 1103/2610 [02:15<02:37,  9.57it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad40] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  42%|████▏     | 1108/2610 [02:16<02:31,  9.91it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad40] moov atom not found
#  43%|████▎     | 1110/2610 [02:16<02:37,  9.55it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  43%|████▎     | 1118/2610 [02:17<02:50,  8.78it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  43%|████▎     | 1121/2610 [02:17<02:21, 10.56it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  43%|████▎     | 1123/2610 [02:17<02:12, 11.18it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  43%|████▎     | 1125/2610 [02:17<02:15, 11.00it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  43%|████▎     | 1130/2610 [02:19<04:42,  5.25it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  44%|████▎     | 1136/2610 [02:19<02:30,  9.77it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  44%|████▎     | 1139/2610 [02:19<02:26, 10.02it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  44%|████▍     | 1145/2610 [02:20<02:47,  8.74it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  44%|████▍     | 1149/2610 [02:20<02:16, 10.67it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  44%|████▍     | 1153/2610 [02:20<02:27,  9.85it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  45%|████▍     | 1163/2610 [02:21<02:29,  9.70it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  45%|████▍     | 1165/2610 [02:22<02:16, 10.60it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  45%|████▍     | 1168/2610 [02:22<02:28,  9.68it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  45%|████▍     | 1174/2610 [02:23<02:58,  8.06it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  45%|████▌     | 1180/2610 [02:23<02:16, 10.44it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  45%|████▌     | 1182/2610 [02:23<02:23,  9.97it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  45%|████▌     | 1185/2610 [02:24<03:56,  6.03it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  46%|████▌     | 1190/2610 [02:25<02:26,  9.71it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  46%|████▌     | 1192/2610 [02:25<02:09, 10.96it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  46%|████▌     | 1194/2610 [02:25<01:57, 12.05it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  46%|████▌     | 1196/2610 [02:25<01:43, 13.60it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  46%|████▌     | 1200/2610 [02:25<02:11, 10.73it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad80] moov atom not found
#  46%|████▌     | 1202/2610 [02:26<02:35,  9.04it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad80] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad80] moov atom not found
#  46%|████▌     | 1205/2610 [02:26<02:47,  8.38it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb057280] moov atom not found
#  46%|████▋     | 1209/2610 [02:26<02:23,  9.77it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad40] moov atom not found
#  46%|████▋     | 1213/2610 [02:27<01:55, 12.11it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb057280] moov atom not found
#  47%|████▋     | 1215/2610 [02:27<02:25,  9.61it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb057280] moov atom not found
#  47%|████▋     | 1227/2610 [02:28<02:26,  9.47it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  47%|████▋     | 1231/2610 [02:29<03:36,  6.37it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  47%|████▋     | 1238/2610 [02:30<03:00,  7.59it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  48%|████▊     | 1243/2610 [02:30<02:07, 10.73it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  48%|████▊     | 1249/2610 [02:30<01:46, 12.73it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  48%|████▊     | 1251/2610 [02:30<01:38, 13.78it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  48%|████▊     | 1253/2610 [02:31<01:31, 14.91it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad40] moov atom not found
#  48%|████▊     | 1258/2610 [02:31<01:41, 13.30it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad40] moov atom not found
#  49%|████▉     | 1275/2610 [02:33<02:19,  9.54it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  49%|████▉     | 1281/2610 [02:33<02:13,  9.93it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  49%|████▉     | 1283/2610 [02:34<01:53, 11.69it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  49%|████▉     | 1288/2610 [02:34<02:14,  9.82it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  49%|████▉     | 1290/2610 [02:34<01:55, 11.41it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  50%|████▉     | 1297/2610 [02:35<02:18,  9.48it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  50%|████▉     | 1301/2610 [02:35<02:01, 10.76it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad40] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  50%|█████     | 1306/2610 [02:36<01:55, 11.25it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  50%|█████     | 1308/2610 [02:36<02:02, 10.64it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# ...
#  82%|████████▏ | 2133/2610 [04:21<00:52,  9.07it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  82%|████████▏ | 2135/2610 [04:22<00:45, 10.34it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  82%|████████▏ | 2139/2610 [04:22<00:46, 10.10it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  82%|████████▏ | 2142/2610 [04:22<00:36, 12.99it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  82%|████████▏ | 2145/2610 [04:22<00:30, 15.07it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  82%|████████▏ | 2150/2610 [04:23<00:56,  8.12it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  82%|████████▏ | 2152/2610 [04:23<00:54,  8.40it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad40] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  83%|████████▎ | 2158/2610 [04:24<01:01,  7.40it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad40] moov atom not found
#  83%|████████▎ | 2160/2610 [04:24<00:57,  7.84it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad40] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad40] moov atom not found
#  83%|████████▎ | 2164/2610 [04:24<00:43, 10.32it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  83%|████████▎ | 2166/2610 [04:25<00:45,  9.85it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb057280] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb057280] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb057280] moov atom not found
#  84%|████████▍ | 2187/2610 [04:27<00:58,  7.22it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  84%|████████▍ | 2189/2610 [04:28<00:56,  7.45it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  84%|████████▍ | 2194/2610 [04:28<00:42,  9.74it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  84%|████████▍ | 2197/2610 [04:28<00:35, 11.58it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  84%|████████▍ | 2201/2610 [04:28<00:27, 14.80it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  84%|████████▍ | 2203/2610 [04:29<00:34, 11.86it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xafffe80] moov atom not found
#  85%|████████▍ | 2206/2610 [04:29<00:41,  9.65it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  85%|████████▍ | 2208/2610 [04:29<00:44,  9.01it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  85%|████████▍ | 2213/2610 [04:30<00:38, 10.35it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  85%|████████▍ | 2217/2610 [04:31<01:06,  5.95it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  85%|████████▌ | 2221/2610 [04:31<00:51,  7.51it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  85%|████████▌ | 2223/2610 [04:31<00:40,  9.66it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb116c40] moov atom not found
#  85%|████████▌ | 2225/2610 [04:31<00:36, 10.59it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb116c40] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb116c40] moov atom not found
#  85%|████████▌ | 2228/2610 [04:32<00:32, 11.84it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  86%|████████▌ | 2236/2610 [04:33<00:56,  6.62it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  86%|████████▌ | 2238/2610 [04:33<00:49,  7.52it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  86%|████████▌ | 2244/2610 [04:34<00:37,  9.87it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  86%|████████▌ | 2250/2610 [04:34<00:45,  7.84it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  87%|████████▋ | 2264/2610 [04:37<00:58,  5.90it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  87%|████████▋ | 2270/2610 [04:38<00:59,  5.72it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  87%|████████▋ | 2275/2610 [04:39<00:47,  7.03it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  87%|████████▋ | 2280/2610 [04:40<01:00,  5.44it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  88%|████████▊ | 2286/2610 [04:41<00:57,  5.64it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  88%|████████▊ | 2290/2610 [04:41<00:34,  9.24it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  88%|████████▊ | 2292/2610 [04:41<00:38,  8.32it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  88%|████████▊ | 2294/2610 [04:41<00:32,  9.74it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  88%|████████▊ | 2297/2610 [04:42<00:24, 12.90it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  88%|████████▊ | 2300/2610 [04:42<00:22, 13.98it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  89%|████████▊ | 2310/2610 [04:44<00:50,  5.95it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  89%|████████▊ | 2313/2610 [04:44<00:50,  5.92it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad40] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  89%|████████▉ | 2320/2610 [04:45<00:40,  7.23it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  89%|████████▉ | 2326/2610 [04:46<00:34,  8.16it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  89%|████████▉ | 2330/2610 [04:46<00:25, 11.09it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  90%|████████▉ | 2340/2610 [04:47<00:28,  9.53it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  90%|████████▉ | 2343/2610 [04:47<00:23, 11.58it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  90%|████████▉ | 2347/2610 [04:47<00:23, 11.31it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad80] moov atom not found
#  90%|█████████ | 2353/2610 [04:48<00:27,  9.36it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  90%|█████████ | 2357/2610 [04:49<00:38,  6.59it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  90%|█████████ | 2361/2610 [04:49<00:33,  7.50it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  91%|█████████ | 2365/2610 [04:50<00:29,  8.19it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb104a80] moov atom not found
#  91%|█████████ | 2368/2610 [04:50<00:27,  8.88it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  91%|█████████ | 2376/2610 [04:51<00:28,  8.19it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  91%|█████████▏| 2387/2610 [04:52<00:36,  6.08it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad40] moov atom not found
#  92%|█████████▏| 2389/2610 [04:52<00:27,  7.89it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  92%|█████████▏| 2392/2610 [04:53<00:24,  8.99it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  92%|█████████▏| 2394/2610 [04:53<00:25,  8.42it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad80] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad80] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad80] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad80] moov atom not found
#  92%|█████████▏| 2399/2610 [04:53<00:22,  9.44it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  92%|█████████▏| 2402/2610 [04:54<00:29,  7.03it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  92%|█████████▏| 2408/2610 [04:55<00:25,  7.81it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  92%|█████████▏| 2411/2610 [04:55<00:27,  7.33it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  93%|█████████▎| 2416/2610 [04:56<00:38,  4.99it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  93%|█████████▎| 2419/2610 [04:57<00:38,  4.92it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  93%|█████████▎| 2424/2610 [04:57<00:24,  7.62it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  93%|█████████▎| 2426/2610 [04:57<00:19,  9.24it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  93%|█████████▎| 2429/2610 [04:57<00:15, 11.83it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb104a80] moov atom not found
#  93%|█████████▎| 2431/2610 [04:58<00:18,  9.79it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  93%|█████████▎| 2435/2610 [04:58<00:14, 11.90it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  93%|█████████▎| 2439/2610 [04:59<00:23,  7.34it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb51ad40] moov atom not found
#  94%|█████████▎| 2443/2610 [04:59<00:23,  7.11it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  94%|█████████▍| 2448/2610 [05:00<00:16, 10.00it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  94%|█████████▍| 2453/2610 [05:00<00:12, 12.76it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  94%|█████████▍| 2458/2610 [05:00<00:15,  9.60it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  94%|█████████▍| 2460/2610 [05:01<00:13, 10.95it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  94%|█████████▍| 2462/2610 [05:01<00:12, 12.28it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  94%|█████████▍| 2465/2610 [05:01<00:10, 13.80it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  95%|█████████▍| 2472/2610 [05:01<00:11, 12.23it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  95%|█████████▍| 2479/2610 [05:02<00:15,  8.70it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb057280] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac2f740] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb057280] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb057280] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb057280] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb057280] moov atom not found
#  95%|█████████▌| 2486/2610 [05:02<00:08, 14.26it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  95%|█████████▌| 2489/2610 [05:03<00:07, 16.09it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  95%|█████████▌| 2492/2610 [05:03<00:06, 18.21it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  96%|█████████▌| 2498/2610 [05:03<00:10, 10.56it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  96%|█████████▌| 2504/2610 [05:04<00:08, 12.93it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  96%|█████████▋| 2513/2610 [05:05<00:14,  6.76it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  97%|█████████▋| 2520/2610 [05:05<00:07, 12.68it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb057280] moov atom not found
#  97%|█████████▋| 2523/2610 [05:06<00:06, 14.49it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  97%|█████████▋| 2526/2610 [05:06<00:07, 11.59it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  97%|█████████▋| 2530/2610 [05:07<00:09,  8.52it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  97%|█████████▋| 2532/2610 [05:07<00:08,  9.33it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  97%|█████████▋| 2537/2610 [05:07<00:06, 11.96it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  97%|█████████▋| 2541/2610 [05:08<00:07,  9.44it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  97%|█████████▋| 2544/2610 [05:08<00:11,  5.71it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  98%|█████████▊| 2547/2610 [05:09<00:11,  5.70it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb057280] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb057280] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb057280] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb057280] moov atom not found
#  98%|█████████▊| 2552/2610 [05:09<00:05,  9.96it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  98%|█████████▊| 2559/2610 [05:09<00:03, 14.76it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  98%|█████████▊| 2565/2610 [05:10<00:03, 12.88it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  99%|█████████▊| 2575/2610 [05:11<00:04,  7.97it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  99%|█████████▉| 2578/2610 [05:11<00:03,  9.06it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  99%|█████████▉| 2581/2610 [05:12<00:03,  7.91it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
#  99%|█████████▉| 2588/2610 [05:12<00:02, 10.38it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
#  99%|█████████▉| 2590/2610 [05:12<00:01, 10.46it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# 100%|█████████▉| 2600/2610 [05:13<00:00, 10.02it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# 100%|█████████▉| 2605/2610 [05:15<00:00,  5.78it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0xb017640] moov atom not found
# 100%|█████████▉| 2609/2610 [05:15<00:00,  6.50it/s][mov,mp4,m4a,3gp,3g2,mj2 @ 0xac0d640] moov atom not found
# 100%|██████████| 2610/2610 [05:15<00:00,  8.27it/s]
# [INFO] Done with test — processed 2610 entries (some skipped if no match).

# %%
import shutil

# Compress the whole 'frames' folder into 'frames.zip'
shutil.make_archive('/kaggle/working/frames', 'zip', '/kaggle/working/frames')
# Out:
# '/kaggle/working/frames.zip'

# %%
# Emotion and Sentiment label mapping
emotion2idx = {'neutral': 0, 'anger': 1, 'disgust': 2, 'sadness': 3, 'joy': 4, 'surprise': 5, 'fear': 6}
sentiment2idx = {'neutral': 0, 'positive': 1, 'negative': 2}

# %%
def build_label_dict(csv_path):
    df = pd.read_csv(csv_path)
    labels = {}
    valid_videos = set()

    print(f"[INFO] Loading labels from {csv_path} with {len(df)} entries")
    
    for _, row in df.iterrows():
        try:
            video_key = f"{row['Dialogue_ID']}_{row['Utterance_ID']}"
            labels[video_key + ".mp4"] = {
                'emotion': emotion2idx[row['Emotion'].lower()],
                'sentiment': sentiment2idx[row['Sentiment'].lower()]
            }
            valid_videos.add(video_key + ".mp4")
        except Exception as e:
            print(f"[ERROR] Failed for row: {row}\n{e}")
    
    print(f"[INFO] Built label dict with {len(labels)} entries")
    return labels

# %%
from torch.utils.data import Dataset
from PIL import Image
import torch
import torchvision.transforms as transforms
import glob

class FrameLevelMELDDataset(Dataset):
    def __init__(self, frames_root, label_dict, transform=None):
        self.samples = []
        self.transform = transform

        print(f"[INFO] Checking frames in: {frames_root}")
        found = 0

        for video_folder in os.listdir(frames_root):
            video_path = os.path.join(frames_root, video_folder)
            if not os.path.isdir(video_path):
                continue

            # Look for any frame_*.jpg
            frame_list = sorted(glob.glob(os.path.join(video_path, 'frame_*.jpg')))
            if not frame_list:
                print(f"[WARN] No frames found in {video_folder}")
                continue

            label_key = f"{video_folder}.mp4"
            if label_key in label_dict:
                # You can choose to use all frames or just the first one
                self.samples.append((frame_list[0], label_dict[label_key], video_folder))  # Added video_folder to the tuple
                found += 1
            else:
                print(f"[WARN] Label missing for {label_key}")

        print(f"[INFO] Loaded {found} valid frame-level samples")

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        frame_path, labels, video_folder = self.samples[idx]  # Unpack the video_folder here
        image = Image.open(frame_path).convert('RGB')
        
        if self.transform:
            image = self.transform(image)
        
        return image, (torch.tensor(labels['sentiment']), torch.tensor(labels['emotion']), video_folder)

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load labels
train_labels = build_label_dict('/kaggle/input/meld-dataset/MELD-RAW/MELD.Raw/train/train_sent_emo.csv')
val_labels = build_label_dict('/kaggle/input/meld-dataset/MELD-RAW/MELD.Raw/dev_sent_emo.csv')
test_labels = build_label_dict('/kaggle/input/meld-dataset/MELD-RAW/MELD.Raw/test_sent_emo.csv')

# Datasets
train_dataset = FrameLevelMELDDataset('/kaggle/working/frames/train', train_labels, transform)
val_dataset = FrameLevelMELDDataset('/kaggle/working/frames/val', val_labels, transform)
test_dataset = FrameLevelMELDDataset('/kaggle/working/frames/test', test_labels, transform)

print(f"[INFO] Train dataset size: {len(train_dataset)}")
print(f"[INFO] Val dataset size: {len(val_dataset)}")
print(f"[INFO] Test dataset size: {len(test_dataset)}")
# Out:
# [INFO] Loading labels from /kaggle/input/meld-dataset/MELD-RAW/MELD.Raw/train/train_sent_emo.csv with 9989 entries
# [INFO] Built label dict with 9989 entries
# [INFO] Loading labels from /kaggle/input/meld-dataset/MELD-RAW/MELD.Raw/dev_sent_emo.csv with 1109 entries
# [INFO] Built label dict with 1109 entries
# [INFO] Loading labels from /kaggle/input/meld-dataset/MELD-RAW/MELD.Raw/test_sent_emo.csv with 2610 entries
# [INFO] Built label dict with 2610 entries
# [INFO] Checking frames in: /kaggle/working/frames/train
# [WARN] No frames found in 125_3
# [INFO] Loaded 9988 valid frame-level samples
# [INFO] Checking frames in: /kaggle/working/frames/val
# [INFO] Loaded 1108 valid frame-level samples
# [INFO] Checking frames in: /kaggle/working/frames/test
# [WARN] No frames found in 168_1
# [WARN] No frames found in 255_5
# [WARN] No frames found in 29_12
# [WARN] No frames found in 186_2
# [WARN] No frames found in 93_13
# [WARN] No frames found in 209_0
# [WARN] No frames found in 34_1
# [WARN] No frames found in 103_2
# [WARN] No frames found in 124_12
# [WARN] No frames found in 190_4
# [WARN] No frames found in 168_10
# [WARN] No frames found in 45_0
# [WARN] No frames found in 153_2
# [WARN] No frames found in 279_15
# [WARN] No frames found in 57_2
# [WARN] No frames found in 223_2
# [WARN] No frames found in 16_3
# [WARN] No frames found in 245_2
# [WARN] No frames found in 267_8
# [WARN] No frames found in 34_4
# [WARN] No frames found in 10_3
# [WARN] No frames found in 250_7
# [WARN] No frames found in 64_15
# [WARN] No frames found in 107_9
# [WARN] No frames found in 239_11
# [WARN] No frames found in 65_3
# [WARN] No frames found in 217_7
# [WARN] No frames found in 16_4
# [WARN] No frames found in 84_1
# [WARN] No frames found in 70_1
# [WARN] No frames found in 268_7
# [WARN] No frames found in 222_9
# [WARN] No frames found in 137_7
# [WARN] No frames found in 222_13
# [WARN] No frames found in 208_7
# [WARN] No frames found in 158_4
# [WARN] No frames found in 120_17
# [WARN] No frames found in 224_6
# [WARN] No frames found in 270_12
# [WARN] No frames found in 209_1
# [WARN] No frames found in 109_6
# [WARN] No frames found in 231_1
# [WARN] No frames found in 224_7
# [WARN] No frames found in 107_12
# [WARN] No frames found in 109_5
# [WARN] No frames found in 126_5
# [WARN] No frames found in 250_5
# [WARN] No frames found in 99_9
# [WARN] No frames found in 215_10
# [WARN] No frames found in 171_7
# [WARN] No frames found in 73_4
# [WARN] No frames found in 25_9
# [WARN] No frames found in 42_3
# [WARN] No frames found in 253_9
# [WARN] No frames found in 70_19
# [WARN] No frames found in 80_5
# [WARN] No frames found in 107_6
# [WARN] No frames found in 189_0
# [WARN] No frames found in 9_15
# [WARN] No frames found in 83_0
# [WARN] No frames found in 93_8
# [WARN] No frames found in 53_5
# [WARN] No frames found in 93_3
# [WARN] No frames found in 170_4
# [WARN] No frames found in 141_1
# [WARN] No frames found in 42_7
# [WARN] No frames found in 145_4
# [WARN] No frames found in 213_4
# [WARN] No frames found in 113_1
# [WARN] No frames found in 47_12
# [WARN] No frames found in 64_2
# [WARN] No frames found in 7_5
# [WARN] No frames found in 236_0
# [WARN] No frames found in 58_5
# [WARN] No frames found in 174_18
# [WARN] No frames found in 199_8
# [WARN] No frames found in 255_0
# [WARN] No frames found in 120_2
# [WARN] No frames found in 111_8
# [WARN] No frames found in 108_8
# [WARN] No frames found in 46_6
# [WARN] No frames found in 194_2
# [WARN] No frames found in 197_4
# [WARN] No frames found in 178_5
# [WARN] No frames found in 140_2
# [WARN] No frames found in 14_6
# [WARN] No frames found in 37_7
# [WARN] No frames found in 156_6
# [WARN] No frames found in 7_0
# [WARN] No frames found in 247_3
# [WARN] No frames found in 34_9
# [WARN] No frames found in 112_13
# [WARN] No frames found in 250_2
# [WARN] No frames found in 270_9
# [WARN] No frames found in 139_6
# [WARN] No frames found in 120_18
# [WARN] No frames found in 196_4
# [WARN] No frames found in 12_6
# [WARN] No frames found in 92_2
# [WARN] No frames found in 195_2
# [WARN] No frames found in 34_6
# [WARN] No frames found in 255_6
# [WARN] No frames found in 175_22
# [WARN] No frames found in 271_2
# [WARN] No frames found in 100_15
# [WARN] No frames found in 119_0
# [WARN] No frames found in 270_14
# [WARN] No frames found in 65_9
# [WARN] No frames found in 127_2
# [WARN] No frames found in 140_1
# [WARN] No frames found in 202_5
# [WARN] No frames found in 143_5
# [WARN] No frames found in 9_7
# [WARN] No frames found in 153_8
# [WARN] No frames found in 232_9
# [WARN] No frames found in 8_0
# [WARN] No frames found in 244_15
# [WARN] No frames found in 198_3
# [WARN] No frames found in 245_4
# [WARN] No frames found in 194_4
# [WARN] No frames found in 266_11
# [WARN] No frames found in 228_3
# [WARN] No frames found in 195_6
# [WARN] No frames found in 230_3
# [WARN] No frames found in 183_0
# [WARN] No frames found in 64_11
# [WARN] No frames found in 54_8
# [WARN] No frames found in 122_4
# [WARN] No frames found in 117_6
# [WARN] No frames found in 109_2
# [WARN] No frames found in 28_11
# [WARN] No frames found in 204_7
# [WARN] No frames found in 161_10
# [WARN] No frames found in 35_3
# [WARN] No frames found in 71_3
# [WARN] No frames found in 156_9
# [WARN] No frames found in 257_3
# [WARN] No frames found in 232_7
# [WARN] No frames found in 239_0
# [WARN] No frames found in 93_11
# [WARN] No frames found in 232_6
# [WARN] No frames found in 243_1
# [WARN] No frames found in 124_1
# [WARN] No frames found in 119_2
# [WARN] No frames found in 192_10
# [WARN] No frames found in 55_1
# [WARN] No frames found in 270_2
# [WARN] No frames found in 196_5
# [WARN] No frames found in 156_1
# [WARN] No frames found in 193_2
# [WARN] No frames found in 53_8
# [WARN] No frames found in 201_9
# [WARN] No frames found in 133_3
# [WARN] No frames found in 137_13
# [WARN] No frames found in 230_8
# [WARN] No frames found in 36_0
# [WARN] No frames found in 71_11
# [WARN] No frames found in 38_3
# [WARN] No frames found in 95_14
# [WARN] No frames found in 160_7
# [WARN] No frames found in 188_2
# [WARN] No frames found in 250_8
# [WARN] No frames found in 157_1
# [WARN] No frames found in 61_0
# [WARN] No frames found in 143_1
# [WARN] No frames found in 273_3
# [WARN] No frames found in 60_0
# [WARN] No frames found in 16_9
# [WARN] No frames found in 238_0
# [WARN] No frames found in 116_2
# [WARN] No frames found in 266_13
# [WARN] No frames found in 160_13
# [WARN] No frames found in 234_12
# [WARN] No frames found in 46_7
# [WARN] No frames found in 119_3
# [WARN] No frames found in 33_6
# [WARN] No frames found in 262_7
# [WARN] No frames found in 259_8
# [WARN] No frames found in 118_4
# [WARN] No frames found in 41_12
# [WARN] No frames found in 202_2
# [WARN] No frames found in 218_2
# [WARN] No frames found in 182_1
# [WARN] No frames found in 231_11
# [WARN] No frames found in 72_2
# [WARN] No frames found in 39_10
# [WARN] No frames found in 43_5
# [WARN] No frames found in 205_2
# [WARN] No frames found in 121_5
# [WARN] No frames found in 244_21
# [WARN] No frames found in 152_0
# [WARN] No frames found in 103_3
# [WARN] No frames found in 108_6
# [WARN] No frames found in 167_7
# [WARN] No frames found in 258_2
# [WARN] No frames found in 65_6
# [WARN] No frames found in 74_2
# [WARN] No frames found in 73_6
# [WARN] No frames found in 17_1
# [WARN] No frames found in 234_10
# [WARN] No frames found in 244_17
# [WARN] No frames found in 95_18
# [WARN] No frames found in 224_4
# [WARN] No frames found in 208_1
# [WARN] No frames found in 64_7
# [WARN] No frames found in 90_3
# [WARN] No frames found in 65_0
# [WARN] No frames found in 120_11
# [WARN] No frames found in 106_2
# [WARN] No frames found in 17_11
# [WARN] No frames found in 266_14
# [WARN] No frames found in 100_19
# [WARN] No frames found in 268_0
# [WARN] No frames found in 47_6
# [WARN] No frames found in 118_5
# [WARN] No frames found in 169_7
# [WARN] No frames found in 167_4
# [WARN] No frames found in 239_8
# [WARN] No frames found in 22_3
# [WARN] No frames found in 145_5
# [WARN] No frames found in 154_5
# [WARN] No frames found in 229_4
# [WARN] No frames found in 261_8
# [WARN] No frames found in 9_11
# [WARN] No frames found in 35_2
# [WARN] No frames found in 214_0
# [WARN] No frames found in 29_3
# [WARN] No frames found in 133_2
# [WARN] No frames found in 107_10
# [WARN] No frames found in 192_0
# [WARN] No frames found in 250_6
# [WARN] No frames found in 28_8
# [WARN] No frames found in 279_6
# [WARN] No frames found in 12_17
# [WARN] No frames found in 54_4
# [WARN] No frames found in 3_4
# [WARN] No frames found in 17_8
# [WARN] No frames found in 254_15
# [WARN] No frames found in 165_4
# [WARN] No frames found in 16_2
# [WARN] No frames found in 199_10
# [WARN] No frames found in 41_7
# [WARN] No frames found in 178_1
# [WARN] No frames found in 152_2
# [WARN] No frames found in 203_7
# [WARN] No frames found in 226_4
# [WARN] No frames found in 271_3
# [WARN] No frames found in 17_29
# [WARN] No frames found in 175_0
# [WARN] No frames found in 54_0
# [WARN] No frames found in 227_1
# [WARN] No frames found in 182_7
# [WARN] No frames found in 267_9
# [WARN] No frames found in 253_2
# [WARN] No frames found in 213_11
# [WARN] No frames found in 19_0
# [WARN] No frames found in 12_10
# [WARN] No frames found in 85_0
# [WARN] No frames found in 183_8
# [WARN] No frames found in 106_0
# [WARN] No frames found in 167_6
# [WARN] No frames found in 41_11
# [WARN] No frames found in 165_3
# [WARN] No frames found in 210_0
# [WARN] No frames found in 47_13
# [WARN] No frames found in 71_0
# [WARN] No frames found in 156_7
# [WARN] No frames found in 105_2
# [WARN] No frames found in 98_6
# [WARN] No frames found in 22_7
# [WARN] No frames found in 235_0
# [WARN] No frames found in 201_10
# [WARN] No frames found in 33_2
# [WARN] No frames found in 14_10
# [WARN] No frames found in 62_0
# [WARN] No frames found in 263_1
# [WARN] No frames found in 7_8
# [WARN] No frames found in 132_9
# [WARN] No frames found in 75_1
# [WARN] No frames found in 60_5
# [WARN] No frames found in 139_8
# [WARN] No frames found in 171_8
# [WARN] No frames found in 3_3
# [WARN] No frames found in 26_0
# [WARN] No frames found in 56_7
# [WARN] No frames found in 167_1
# [WARN] No frames found in 34_8
# [WARN] No frames found in 121_0
# [WARN] No frames found in 199_1
# [WARN] No frames found in 195_9
# [WARN] No frames found in 161_9
# [WARN] No frames found in 211_4
# [WARN] No frames found in 97_1
# [WARN] No frames found in 194_0
# [WARN] No frames found in 73_9
# [WARN] No frames found in 263_7
# [WARN] No frames found in 98_10
# [WARN] No frames found in 99_4
# [WARN] No frames found in 47_5
# [WARN] No frames found in 278_12
# [WARN] No frames found in 22_10
# [WARN] No frames found in 189_4
# [WARN] No frames found in 113_13
# [WARN] No frames found in 174_11
# [WARN] No frames found in 240_1
# [WARN] No frames found in 166_6
# [WARN] No frames found in 102_6
# [WARN] No frames found in 78_4
# [WARN] No frames found in 107_11
# [WARN] No frames found in 112_8
# [WARN] No frames found in 73_1
# [WARN] No frames found in 163_5
# [WARN] No frames found in 253_6
# [WARN] No frames found in 72_16
# [WARN] No frames found in 169_13
# [WARN] No frames found in 123_1
# [WARN] No frames found in 8_5
# [WARN] No frames found in 70_9
# [WARN] No frames found in 109_0
# [WARN] No frames found in 150_1
# [WARN] No frames found in 211_0
# [WARN] No frames found in 53_1
# [WARN] No frames found in 132_8
# [WARN] No frames found in 114_4
# [WARN] No frames found in 130_11
# [WARN] No frames found in 77_3
# [WARN] No frames found in 191_7
# [WARN] No frames found in 74_3
# [WARN] No frames found in 54_9
# [WARN] No frames found in 231_4
# [WARN] No frames found in 215_6
# [WARN] No frames found in 70_12
# [WARN] No frames found in 231_10
# [WARN] No frames found in 83_4
# [WARN] No frames found in 60_6
# [WARN] No frames found in 29_10
# [WARN] No frames found in 201_0
# [WARN] No frames found in 268_2
# [WARN] No frames found in 146_1
# [WARN] No frames found in 9_10
# [WARN] No frames found in 80_4
# [WARN] No frames found in 223_1
# [WARN] No frames found in 13_4
# [WARN] No frames found in 65_7
# [WARN] No frames found in 7_7
# [WARN] No frames found in 195_1
# [WARN] No frames found in 42_2
# [WARN] No frames found in 267_10
# [WARN] No frames found in 102_4
# [WARN] No frames found in 224_5
# [WARN] No frames found in 17_31
# [WARN] No frames found in 268_11
# [WARN] No frames found in 5_5
# [WARN] No frames found in 20_7
# [WARN] No frames found in 279_12
# [WARN] No frames found in 75_2
# [WARN] No frames found in 110_4
# [WARN] No frames found in 75_5
# [WARN] No frames found in 232_4
# [WARN] No frames found in 154_7
# [WARN] No frames found in 266_1
# [WARN] No frames found in 240_0
# [WARN] No frames found in 93_2
# [WARN] No frames found in 52_2
# [WARN] No frames found in 270_13
# [WARN] No frames found in 268_6
# [WARN] No frames found in 17_12
# [WARN] No frames found in 184_9
# [WARN] No frames found in 73_10
# [WARN] No frames found in 80_3
# [WARN] No frames found in 126_2
# [WARN] No frames found in 146_2
# [WARN] No frames found in 125_10
# [WARN] No frames found in 129_7
# [WARN] No frames found in 187_2
# [WARN] No frames found in 175_8
# [WARN] No frames found in 100_1
# [WARN] No frames found in 272_5
# [WARN] No frames found in 278_4
# [WARN] No frames found in 194_1
# [WARN] No frames found in 160_1
# [WARN] No frames found in 196_13
# [WARN] No frames found in 4_6
# [WARN] No frames found in 226_5
# [WARN] No frames found in 180_8
# [WARN] No frames found in 129_6
# [WARN] No frames found in 100_3
# [WARN] No frames found in 277_0
# [WARN] No frames found in 240_13
# [WARN] No frames found in 100_4
# [WARN] No frames found in 49_16
# [WARN] No frames found in 113_9
# [WARN] No frames found in 265_1
# [WARN] No frames found in 57_1
# [WARN] No frames found in 173_18
# [WARN] No frames found in 9_5
# [WARN] No frames found in 244_0
# [WARN] No frames found in 166_4
# [WARN] No frames found in 47_2
# [WARN] No frames found in 7_3
# [WARN] No frames found in 39_2
# [WARN] No frames found in 178_8
# [WARN] No frames found in 128_1
# [WARN] No frames found in 6_2
# [WARN] No frames found in 155_5
# [WARN] No frames found in 189_3
# [WARN] No frames found in 18_1
# [WARN] No frames found in 128_5
# [WARN] No frames found in 234_11
# [WARN] No frames found in 16_5
# [WARN] No frames found in 153_5
# [WARN] No frames found in 120_1
# [WARN] No frames found in 171_6
# [WARN] No frames found in 107_4
# [WARN] No frames found in 232_5
# [WARN] No frames found in 136_0
# [WARN] No frames found in 100_5
# [WARN] No frames found in 94_0
# [WARN] No frames found in 95_17
# [WARN] No frames found in 266_2
# [WARN] No frames found in 17_18
# [WARN] No frames found in 49_6
# [WARN] No frames found in 57_5
# [WARN] No frames found in 259_13
# [WARN] No frames found in 17_32
# [WARN] No frames found in 169_11
# [WARN] No frames found in 5_8
# [WARN] No frames found in 264_1
# [WARN] No frames found in 33_1
# [WARN] No frames found in 112_3
# [WARN] No frames found in 175_13
# [WARN] No frames found in 170_0
# [WARN] No frames found in 68_11
# [WARN] No frames found in 47_11
# [WARN] No frames found in 113_8
# [WARN] No frames found in 82_0
# [WARN] No frames found in 21_1
# [WARN] No frames found in 266_12
# [WARN] No frames found in 272_0
# [WARN] No frames found in 112_9
# [WARN] No frames found in 68_14
# [WARN] No frames found in 77_1
# [WARN] No frames found in 153_0
# [WARN] No frames found in 25_10
# [WARN] No frames found in 229_6
# [WARN] No frames found in 22_19
# [WARN] No frames found in 195_5
# [WARN] No frames found in 144_1
# [WARN] No frames found in 213_3
# [WARN] No frames found in 37_6
# [WARN] No frames found in 219_1
# [WARN] No frames found in 56_10
# [WARN] No frames found in 218_1
# [WARN] No frames found in 188_4
# [WARN] No frames found in 252_8
# [WARN] No frames found in 64_0
# [WARN] No frames found in 113_16
# [WARN] No frames found in 121_1
# [WARN] No frames found in 47_1
# [WARN] No frames found in 71_9
# [WARN] No frames found in 184_5
# [WARN] No frames found in 53_2
# [WARN] No frames found in 196_9
# [WARN] No frames found in 70_10
# [WARN] No frames found in 20_0
# [WARN] No frames found in 71_12
# [WARN] No frames found in 22_6
# [WARN] No frames found in 153_11
# [WARN] No frames found in 237_3
# [WARN] No frames found in 258_10
# [WARN] No frames found in 266_4
# [WARN] No frames found in 201_4
# [WARN] No frames found in 83_6
# [WARN] No frames found in 155_0
# [WARN] No frames found in 168_17
# [WARN] No frames found in 32_4
# [WARN] No frames found in 72_10
# [WARN] No frames found in 257_1
# [WARN] No frames found in 203_10
# [WARN] No frames found in 192_11
# [WARN] No frames found in 11_4
# [WARN] No frames found in 61_2
# [WARN] No frames found in 7_6
# [WARN] No frames found in 12_7
# [WARN] No frames found in 244_5
# [WARN] No frames found in 7_1
# [WARN] No frames found in 230_1
# [WARN] No frames found in 118_2
# [WARN] No frames found in 47_0
# [WARN] No frames found in 45_8
# [WARN] No frames found in 56_3
# [WARN] No frames found in 133_8
# [WARN] No frames found in 155_2
# [WARN] No frames found in 72_3
# [WARN] No frames found in 131_7
# [WARN] No frames found in 20_6
# [WARN] No frames found in 110_6
# [WARN] No frames found in 139_2
# [WARN] No frames found in 94_1
# [WARN] No frames found in 6_1
# [WARN] No frames found in 269_0
# [WARN] No frames found in 231_2
# [WARN] No frames found in 272_4
# [WARN] No frames found in 226_6
# [WARN] No frames found in 32_5
# [WARN] No frames found in 154_4
# [WARN] No frames found in 250_1
# [WARN] No frames found in 125_5
# [WARN] No frames found in 126_3
# [WARN] No frames found in 124_0
# [WARN] No frames found in 145_10
# [WARN] No frames found in 52_8
# [WARN] No frames found in 60_1
# [WARN] No frames found in 68_4
# [WARN] No frames found in 252_17
# [WARN] No frames found in 78_7
# [WARN] No frames found in 204_8
# [WARN] No frames found in 132_1
# [WARN] No frames found in 244_9
# [WARN] No frames found in 24_3
# [WARN] No frames found in 128_9
# [WARN] No frames found in 204_6
# [WARN] No frames found in 113_5
# [WARN] No frames found in 270_6
# [WARN] No frames found in 42_1
# [WARN] No frames found in 44_3
# [WARN] No frames found in 205_5
# [WARN] No frames found in 121_4
# [WARN] No frames found in 240_3
# [WARN] No frames found in 278_6
# [WARN] No frames found in 154_2
# [WARN] No frames found in 102_5
# [WARN] No frames found in 184_7
# [WARN] No frames found in 75_4
# [WARN] No frames found in 54_10
# [WARN] No frames found in 38_0
# [WARN] No frames found in 168_11
# [WARN] No frames found in 64_8
# [WARN] No frames found in 260_8
# [WARN] No frames found in 117_5
# [WARN] No frames found in 237_7
# [WARN] No frames found in 223_4
# [WARN] No frames found in 223_6
# [WARN] No frames found in 160_12
# [WARN] No frames found in 160_2
# [WARN] No frames found in 21_5
# [WARN] No frames found in 92_3
# [WARN] No frames found in 169_20
# [WARN] No frames found in 15_2
# [WARN] No frames found in 153_1
# [WARN] No frames found in 215_9
# [WARN] No frames found in 195_4
# [WARN] No frames found in 116_6
# [WARN] No frames found in 229_3
# [WARN] No frames found in 215_2
# [WARN] No frames found in 252_18
# [WARN] No frames found in 262_10
# [WARN] No frames found in 112_2
# [WARN] No frames found in 111_0
# [WARN] No frames found in 96_13
# [WARN] No frames found in 175_6
# [WARN] No frames found in 156_8
# [WARN] No frames found in 108_9
# [WARN] No frames found in 168_7
# [WARN] No frames found in 156_12
# [WARN] No frames found in 120_8
# [WARN] No frames found in 41_2
# [WARN] No frames found in 70_14
# [WARN] No frames found in 9_12
# [WARN] No frames found in 260_4
# [WARN] No frames found in 41_0
# [WARN] No frames found in 263_0
# [WARN] No frames found in 208_4
# [WARN] No frames found in 195_7
# [WARN] No frames found in 140_14
# [WARN] No frames found in 196_12
# [WARN] No frames found in 166_10
# [WARN] No frames found in 120_3
# [WARN] No frames found in 230_7
# [WARN] No frames found in 78_9
# [WARN] No frames found in 70_16
# [WARN] No frames found in 102_3
# [WARN] No frames found in 76_13
# [WARN] No frames found in 245_3
# [WARN] No frames found in 37_5
# [WARN] No frames found in 4_7
# [WARN] No frames found in 109_3
# [WARN] No frames found in 70_21
# [WARN] No frames found in 127_4
# [WARN] No frames found in 78_1
# [WARN] No frames found in 126_1
# [WARN] No frames found in 237_8
# [WARN] No frames found in 198_4
# [WARN] No frames found in 164_2
# [WARN] No frames found in 117_8
# [WARN] No frames found in 98_1
# [WARN] No frames found in 85_5
# [WARN] No frames found in 137_12
# [WARN] No frames found in 96_15
# [WARN] No frames found in 278_13
# [WARN] No frames found in 22_18
# [WARN] No frames found in 76_8
# [WARN] No frames found in 240_11
# [WARN] No frames found in 56_8
# [WARN] No frames found in 30_3
# [WARN] No frames found in 22_11
# [WARN] No frames found in 257_2
# [WARN] No frames found in 70_22
# [WARN] No frames found in 129_1
# [WARN] No frames found in 259_11
# [WARN] No frames found in 193_3
# [WARN] No frames found in 231_13
# [WARN] No frames found in 21_6
# [WARN] No frames found in 185_4
# [WARN] No frames found in 186_3
# [WARN] No frames found in 32_12
# [WARN] No frames found in 175_2
# [WARN] No frames found in 153_3
# [WARN] No frames found in 158_2
# [WARN] No frames found in 182_0
# [WARN] No frames found in 125_13
# [WARN] No frames found in 23_1
# [WARN] No frames found in 83_9
# [WARN] No frames found in 83_10
# [WARN] No frames found in 254_4
# [WARN] No frames found in 55_2
# [WARN] No frames found in 107_3
# [WARN] No frames found in 183_1
# [WARN] No frames found in 270_0
# [WARN] No frames found in 184_6
# [WARN] No frames found in 12_15
# [WARN] No frames found in 256_0
# [WARN] No frames found in 9_3
# [WARN] No frames found in 218_0
# [WARN] No frames found in 78_3
# [WARN] No frames found in 163_6
# [WARN] No frames found in 249_2
# [WARN] No frames found in 1_5
# [WARN] No frames found in 175_4
# [WARN] No frames found in 49_11
# [WARN] No frames found in 181_0
# [WARN] No frames found in 70_15
# [WARN] No frames found in 13_0
# [WARN] No frames found in 175_5
# [WARN] No frames found in 49_7
# [WARN] No frames found in 278_7
# [WARN] No frames found in 123_15
# [WARN] No frames found in 45_4
# [WARN] No frames found in 250_0
# [WARN] No frames found in 55_0
# [WARN] No frames found in 216_3
# [WARN] No frames found in 148_0
# [WARN] No frames found in 2_1
# [WARN] No frames found in 118_11
# [WARN] No frames found in 255_7
# [WARN] No frames found in 233_2
# [WARN] No frames found in 195_8
# [WARN] No frames found in 41_3
# [WARN] No frames found in 259_7
# [WARN] No frames found in 158_5
# [WARN] No frames found in 210_4
# [WARN] No frames found in 56_5
# [WARN] No frames found in 112_15
# [WARN] No frames found in 126_12
# [WARN] No frames found in 37_4
# [WARN] No frames found in 53_6
# [WARN] No frames found in 217_6
# [WARN] No frames found in 12_9
# [WARN] No frames found in 213_5
# [WARN] No frames found in 110_0
# [WARN] No frames found in 266_10
# [WARN] No frames found in 17_9
# [WARN] No frames found in 124_14
# [WARN] No frames found in 68_12
# [WARN] No frames found in 57_4
# [WARN] No frames found in 49_3
# [WARN] No frames found in 239_4
# [WARN] No frames found in 95_13
# [WARN] No frames found in 142_1
# [WARN] No frames found in 15_5
# [WARN] No frames found in 169_21
# [WARN] No frames found in 88_7
# [WARN] No frames found in 153_10
# [WARN] No frames found in 165_2
# [WARN] No frames found in 5_0
# [WARN] No frames found in 8_4
# [WARN] No frames found in 265_0
# [WARN] No frames found in 87_1
# [WARN] No frames found in 262_6
# [WARN] No frames found in 90_4
# [WARN] No frames found in 13_6
# [WARN] No frames found in 107_0
# [WARN] No frames found in 184_14
# [WARN] No frames found in 28_14
# [WARN] No frames found in 90_1
# [WARN] No frames found in 43_4
# [WARN] No frames found in 144_4
# [WARN] No frames found in 154_13
# [WARN] No frames found in 65_2
# [WARN] No frames found in 211_5
# [WARN] No frames found in 244_16
# [WARN] No frames found in 54_3
# [WARN] No frames found in 66_1
# [WARN] No frames found in 259_5
# [WARN] No frames found in 113_15
# [WARN] No frames found in 274_2
# [WARN] No frames found in 39_9
# [WARN] No frames found in 68_3
# [WARN] No frames found in 133_0
# [WARN] No frames found in 228_2
# [WARN] No frames found in 20_5
# [WARN] No frames found in 128_8
# [WARN] No frames found in 174_1
# [WARN] No frames found in 223_5
# [WARN] No frames found in 216_0
# [WARN] No frames found in 48_0
# [WARN] No frames found in 12_0
# [WARN] No frames found in 3_0
# [WARN] No frames found in 206_2
# [WARN] No frames found in 4_4
# [WARN] No frames found in 201_11
# [WARN] No frames found in 260_0
# [WARN] No frames found in 161_3
# [WARN] No frames found in 115_2
# [WARN] No frames found in 120_4
# [WARN] No frames found in 264_0
# [WARN] No frames found in 99_2
# [WARN] No frames found in 102_1
# [WARN] No frames found in 96_16
# [WARN] No frames found in 16_1
# [WARN] No frames found in 274_0
# [WARN] No frames found in 169_6
# [WARN] No frames found in 58_8
# [WARN] No frames found in 25_5
# [WARN] No frames found in 21_3
# [WARN] No frames found in 115_3
# [WARN] No frames found in 233_3
# [WARN] No frames found in 130_6
# [WARN] No frames found in 253_3
# [WARN] No frames found in 2_3
# [WARN] No frames found in 170_3
# [WARN] No frames found in 78_8
# [WARN] No frames found in 246_12
# [WARN] No frames found in 269_3
# [WARN] No frames found in 78_6
# [WARN] No frames found in 176_1
# [WARN] No frames found in 144_6
# [WARN] No frames found in 199_0
# [WARN] No frames found in 238_1
# [WARN] No frames found in 264_2
# [WARN] No frames found in 269_2
# [WARN] No frames found in 59_1
# [WARN] No frames found in 225_0
# [WARN] No frames found in 156_4
# [WARN] No frames found in 178_0
# [WARN] No frames found in 210_9
# [WARN] No frames found in 252_14
# [WARN] No frames found in 80_2
# [WARN] No frames found in 221_1
# [WARN] No frames found in 228_12
# [WARN] No frames found in 83_7
# [WARN] No frames found in 13_1
# [WARN] No frames found in 168_9
# [WARN] No frames found in 213_1
# [WARN] No frames found in 157_2
# [WARN] No frames found in 278_2
# [WARN] No frames found in 187_1
# [WARN] No frames found in 120_9
# [WARN] No frames found in 224_0
# [WARN] No frames found in 255_2
# [WARN] No frames found in 10_1
# [WARN] No frames found in 261_3
# [WARN] No frames found in 237_10
# [WARN] No frames found in 188_5
# [WARN] No frames found in 58_3
# [WARN] No frames found in 151_1
# [WARN] No frames found in 154_16
# [WARN] No frames found in 229_2
# [WARN] No frames found in 3_1
# [WARN] No frames found in 34_12
# [WARN] No frames found in 184_1
# [WARN] No frames found in 161_11
# [WARN] No frames found in 41_1
# [WARN] No frames found in 233_1
# [WARN] No frames found in 112_10
# [WARN] No frames found in 111_2
# [WARN] No frames found in 12_18
# [WARN] No frames found in 174_10
# [WARN] No frames found in 169_0
# [WARN] No frames found in 229_0
# [WARN] No frames found in 255_4
# [WARN] No frames found in 203_1
# [WARN] No frames found in 58_16
# [WARN] No frames found in 228_8
# [WARN] No frames found in 67_0
# [WARN] No frames found in 230_0
# [WARN] No frames found in 202_0
# [WARN] No frames found in 110_8
# [WARN] No frames found in 272_3
# [WARN] No frames found in 137_14
# [WARN] No frames found in 111_12
# [WARN] No frames found in 17_25
# [WARN] No frames found in 150_4
# [WARN] No frames found in 126_13
# [WARN] No frames found in 50_3
# [WARN] No frames found in 146_4
# [WARN] No frames found in 144_12
# [WARN] No frames found in 132_2
# [WARN] No frames found in 206_4
# [WARN] No frames found in 217_2
# [WARN] No frames found in 54_2
# [WARN] No frames found in 124_5
# [WARN] No frames found in 262_11
# [WARN] No frames found in 244_20
# [WARN] No frames found in 96_12
# [WARN] No frames found in 258_6
# [WARN] No frames found in 52_0
# [WARN] No frames found in 231_12
# [WARN] No frames found in 237_1
# [WARN] No frames found in 42_0
# [WARN] No frames found in 164_0
# [WARN] No frames found in 167_9
# [WARN] No frames found in 97_7
# [WARN] No frames found in 96_20
# [WARN] No frames found in 196_3
# [WARN] No frames found in 31_0
# [WARN] No frames found in 117_3
# [WARN] No frames found in 72_6
# [WARN] No frames found in 217_9
# [WARN] No frames found in 167_5
# [WARN] No frames found in 169_18
# [WARN] No frames found in 64_12
# [WARN] No frames found in 45_7
# [WARN] No frames found in 88_13
# [WARN] No frames found in 111_3
# [WARN] No frames found in 199_11
# [WARN] No frames found in 115_0
# [WARN] No frames found in 243_0
# [WARN] No frames found in 119_1
# [WARN] No frames found in 15_3
# [WARN] No frames found in 140_3
# [WARN] No frames found in 122_0
# [WARN] No frames found in 174_6
# [WARN] No frames found in 25_12
# [WARN] No frames found in 145_0
# [WARN] No frames found in 174_0
# [WARN] No frames found in 17_26
# [WARN] No frames found in 84_2
# [WARN] No frames found in 130_12
# [WARN] No frames found in 156_11
# [WARN] No frames found in 112_20
# [WARN] No frames found in 167_14
# [WARN] No frames found in 15_0
# [WARN] No frames found in 9_16
# [WARN] No frames found in 175_3
# [WARN] No frames found in 271_4
# [WARN] No frames found in 68_1
# [WARN] No frames found in 9_13
# [WARN] No frames found in 173_13
# [WARN] No frames found in 112_16
# [WARN] No frames found in 103_5
# [WARN] No frames found in 132_13
# [WARN] No frames found in 99_8
# [WARN] No frames found in 123_9
# [WARN] No frames found in 108_4
# [WARN] No frames found in 199_15
# [WARN] No frames found in 63_0
# [WARN] No frames found in 123_13
# [WARN] No frames found in 167_2
# [WARN] No frames found in 130_2
# [WARN] No frames found in 96_8
# [WARN] No frames found in 17_10
# [WARN] No frames found in 202_6
# [WARN] No frames found in 172_1
# [WARN] No frames found in 139_7
# [WARN] No frames found in 45_2
# [WARN] No frames found in 222_1
# [WARN] No frames found in 100_14
# [WARN] No frames found in 169_10
# [WARN] No frames found in 30_4
# [WARN] No frames found in 70_18
# [WARN] No frames found in 228_7
# [WARN] No frames found in 181_5
# [WARN] No frames found in 252_0
# [WARN] No frames found in 247_2
# [WARN] No frames found in 1_3
# [WARN] No frames found in 60_4
# [WARN] No frames found in 204_0
# [WARN] No frames found in 67_3
# [WARN] No frames found in 65_4
# [WARN] No frames found in 2_4
# [WARN] No frames found in 171_4
# [WARN] No frames found in 51_0
# [WARN] No frames found in 269_4
# [WARN] No frames found in 12_13
# [WARN] No frames found in 12_2
# [WARN] No frames found in 253_10
# [WARN] No frames found in 111_13
# [WARN] No frames found in 164_1
# [WARN] No frames found in 84_0
# [WARN] No frames found in 154_1
# [WARN] No frames found in 48_2
# [WARN] No frames found in 156_10
# [WARN] No frames found in 39_1
# [WARN] No frames found in 145_1
# [WARN] No frames found in 225_5
# [WARN] No frames found in 263_9
# [WARN] No frames found in 237_2
# [WARN] No frames found in 157_7
# [WARN] No frames found in 59_2
# [WARN] No frames found in 154_20
# [WARN] No frames found in 112_21
# [WARN] No frames found in 206_3
# [WARN] No frames found in 128_0
# [WARN] No frames found in 278_5
# [WARN] No frames found in 271_5
# [WARN] No frames found in 28_12
# [WARN] No frames found in 37_1
# [WARN] No frames found in 85_2
# [WARN] No frames found in 191_2
# [WARN] No frames found in 175_1
# [WARN] No frames found in 266_6
# [WARN] No frames found in 208_11
# [WARN] No frames found in 199_9
# [WARN] No frames found in 28_10
# [WARN] No frames found in 215_1
# [WARN] No frames found in 65_10
# [WARN] No frames found in 241_8
# [WARN] No frames found in 12_1
# [WARN] No frames found in 205_7
# [WARN] No frames found in 116_0
# [WARN] No frames found in 211_3
# [WARN] No frames found in 39_3
# [WARN] No frames found in 227_2
# [WARN] No frames found in 198_2
# [WARN] No frames found in 137_4
# [WARN] No frames found in 242_7
# [WARN] No frames found in 279_11
# [WARN] No frames found in 268_1
# [WARN] No frames found in 189_6
# [WARN] No frames found in 271_0
# [WARN] No frames found in 69_4
# [WARN] No frames found in 169_1
# [WARN] No frames found in 28_0
# [WARN] No frames found in 45_6
# [WARN] No frames found in 276_0
# [WARN] No frames found in 263_8
# [WARN] No frames found in 12_8
# [WARN] No frames found in 272_1
# [WARN] No frames found in 57_3
# [WARN] No frames found in 34_0
# [WARN] No frames found in 99_0
# [WARN] No frames found in 9_17
# [WARN] No frames found in 208_0
# [WARN] No frames found in 49_14
# [WARN] No frames found in 33_3
# [WARN] No frames found in 185_0
# [WARN] No frames found in 187_3
# [WARN] No frames found in 14_9
# [WARN] No frames found in 174_14
# [WARN] No frames found in 169_19
# [WARN] No frames found in 130_0
# [WARN] No frames found in 76_5
# [WARN] No frames found in 2_2
# [WARN] No frames found in 234_8
# [WARN] No frames found in 105_0
# [WARN] No frames found in 183_7
# [WARN] No frames found in 39_5
# [WARN] No frames found in 118_9
# [WARN] No frames found in 43_2
# [WARN] No frames found in 141_2
# [WARN] No frames found in 246_2
# [WARN] No frames found in 199_14
# [WARN] No frames found in 168_12
# [WARN] No frames found in 237_5
# [WARN] No frames found in 175_16
# [WARN] No frames found in 12_16
# [WARN] No frames found in 15_1
# [WARN] No frames found in 96_17
# [WARN] No frames found in 88_4
# [WARN] No frames found in 35_0
# [WARN] No frames found in 180_3
# [WARN] No frames found in 155_8
# [WARN] No frames found in 198_5
# [WARN] No frames found in 250_4
# [WARN] No frames found in 201_1
# [WARN] No frames found in 161_2
# [WARN] No frames found in 149_0
# [WARN] No frames found in 97_2
# [WARN] No frames found in 157_3
# [WARN] No frames found in 49_15
# [WARN] No frames found in 225_2
# [WARN] No frames found in 52_7
# [WARN] No frames found in 96_7
# [WARN] No frames found in 17_19
# [WARN] No frames found in 266_16
# [WARN] No frames found in 99_6
# [WARN] No frames found in 185_1
# [WARN] No frames found in 262_3
# [WARN] No frames found in 201_7
# [WARN] No frames found in 123_10
# [WARN] No frames found in 196_1
# [WARN] No frames found in 70_17
# [WARN] No frames found in 252_3
# [WARN] No frames found in 168_16
# [WARN] No frames found in 98_2
# [WARN] No frames found in 70_3
# [WARN] No frames found in 241_3
# [WARN] No frames found in 259_0
# [WARN] No frames found in 73_7
# [WARN] No frames found in 118_3
# [WARN] No frames found in 58_2
# [WARN] No frames found in 266_5
# [WARN] No frames found in 49_4
# [WARN] No frames found in 274_1
# [INFO] Loaded 1595 valid frame-level samples
# [INFO] Train dataset size: 9988
# [INFO] Val dataset size: 1108
# [INFO] Test dataset size: 1595

# %%
# DataLoaders
from torch.utils.data import DataLoader

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=4, shuffle=False)  # smaller batch size for videos
test_loader = DataLoader(test_dataset, batch_size=4, shuffle=False)

# %%
import torch
import torch.nn as nn

# Check if a GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class MELD_CNN(nn.Module):
    def __init__(self, feature_dim=100):
        super(MELD_CNN, self).__init__()
        
        # Base CNN same as before
        self.conv1 = nn.Conv2d(3, 16, 3, padding=1)
        self.leakyrelu1 = nn.LeakyReLU(0.1)
        self.maxpool1 = nn.MaxPool2d(2, 2)
        self.dropout1 = nn.Dropout2d(0.2)
        
        self.conv2 = nn.Conv2d(16, 32, 3, padding=1)
        self.leakyrelu2 = nn.LeakyReLU(0.1)
        self.batchnorm1 = nn.BatchNorm2d(32)
        self.maxpool2 = nn.MaxPool2d(2, 2)
        self.dropout2 = nn.Dropout2d(0.2)
        
        self.conv3 = nn.Conv2d(32, 64, 3, padding=1)
        self.leakyrelu3 = nn.LeakyReLU(0.1)
        self.batchnorm2 = nn.BatchNorm2d(64)
        self.maxpool3 = nn.MaxPool2d(2, 2)
        self.dropout3 = nn.Dropout2d(0.2)
        
        self.conv4 = nn.Conv2d(64, 128, 3, padding=1)
        self.leakyrelu4 = nn.LeakyReLU(0.1)
        self.batchnorm3 = nn.BatchNorm2d(128)
        self.maxpool4 = nn.MaxPool2d(2, 2)
        self.dropout4 = nn.Dropout2d(0.2)
        
        self.conv5 = nn.Conv2d(128, 256, 3, padding=1)
        self.leakyrelu5 = nn.LeakyReLU(0.1)
        self.batchnorm4 = nn.BatchNorm2d(256)
        self.maxpool5 = nn.MaxPool2d(2, 2)
        self.dropout5 = nn.Dropout2d(0.2)

        # Flatten and FC
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(7 * 7 * 256, feature_dim)
        self.relu_fc = nn.LeakyReLU(0.1)

        # Output heads
        self.sentiment_head = nn.Linear(feature_dim, 3)  # Sentiment: 3 classes
        self.emotion_head = nn.Linear(feature_dim, 7)    # Emotion: 7 classes

    def forward(self, x):
        x = self.leakyrelu1(self.conv1(x))
        x = self.maxpool1(x)
        x = self.dropout1(x)
        
        x = self.leakyrelu2(self.conv2(x))
        x = self.batchnorm1(x)
        x = self.maxpool2(x)
        x = self.dropout2(x)
        
        x = self.leakyrelu3(self.conv3(x))
        x = self.batchnorm2(x)
        x = self.maxpool3(x)
        x = self.dropout3(x)
        
        x = self.leakyrelu4(self.conv4(x))
        x = self.batchnorm3(x)
        x = self.maxpool4(x)
        x = self.dropout4(x)
        
        x = self.leakyrelu5(self.conv5(x))
        x = self.batchnorm4(x)
        x = self.maxpool5(x)
        x = self.dropout5(x)

        x = self.flatten(x)
        features = self.relu_fc(self.fc1(x))

        # Predict both sentiment and emotion
        sentiment_logits = self.sentiment_head(features)
        emotion_logits = self.emotion_head(features)

        return sentiment_logits, emotion_logits

# Create an instance of the AutismCNN model and move it to the GPU
model = MELD_CNN().to(device)

# %%
import torch.nn as nn
import torch.optim as optim

# Define loss functions for both outputs
sentiment_criterion = nn.CrossEntropyLoss()
emotion_criterion = nn.CrossEntropyLoss()

sentiment_criterion = sentiment_criterion.to(device)
emotion_criterion = emotion_criterion.to(device)

# Optimizer (unchanged)
learning_rate = 0.001
beta1 = 0.9
beta2 = 0.999
epsilon = 1e-7

optimizer = optim.Adam(model.parameters(), lr=learning_rate, betas=(beta1, beta2), eps=epsilon)

# %%
from sklearn.metrics import accuracy_score
from collections import defaultdict, Counter
from tqdm import tqdm
import numpy as np
import torch

def aggregate_predictions(preds_dict):
    final_preds = {}
    for video, preds in preds_dict.items():
        votes = Counter(preds)
        final_preds[video] = votes.most_common(1)[0][0]
    return final_preds

train_losses, val_losses = [], []
train_sent_losses, val_sent_losses = [], []
train_emo_losses, val_emo_losses = [], []
train_sent_accs, val_sent_accs = [], []
train_emo_accs, val_emo_accs = [], []

num_epochs = 50
patience = 5
min_delta = 0.001
best_val_loss = float('inf')
epochs_without_improvement = 0

for epoch in range(num_epochs):
    print(f"\n===== Epoch {epoch+1}/{num_epochs} =====")

    # ---------- Training ----------
    model.train()
    total_train_loss, sent_loss_sum, emo_loss_sum = 0.0, 0.0, 0.0
    train_sent_preds, train_emo_preds = [], []
    train_sent_labels, train_emo_labels = [], []

    for images, (sentiment_labels, emotion_labels, video_folder) in tqdm(train_loader, desc=f"Train"):
        images = images.to(device)
        sentiment_labels = sentiment_labels.to(device)
        emotion_labels = emotion_labels.to(device)

        optimizer.zero_grad()
        sent_out, emo_out = model(images)

        loss_sent = sentiment_criterion(sent_out, sentiment_labels)
        loss_emo = emotion_criterion(emo_out, emotion_labels)
        loss = loss_sent + loss_emo
        loss.backward()
        optimizer.step()

        total_train_loss += loss.item()
        sent_loss_sum += loss_sent.item()
        emo_loss_sum += loss_emo.item()

        train_sent_preds.extend(sent_out.argmax(dim=1).cpu().numpy())
        train_emo_preds.extend(emo_out.argmax(dim=1).cpu().numpy())
        train_sent_labels.extend(sentiment_labels.cpu().numpy())
        train_emo_labels.extend(emotion_labels.cpu().numpy())

    avg_train_loss = total_train_loss / len(train_loader)
    avg_train_sent_loss = sent_loss_sum / len(train_loader)
    avg_train_emo_loss = emo_loss_sum / len(train_loader)
    train_sent_acc = accuracy_score(train_sent_labels, train_sent_preds)
    train_emo_acc = accuracy_score(train_emo_labels, train_emo_preds)

    train_losses.append(avg_train_loss)
    train_sent_losses.append(avg_train_sent_loss)
    train_emo_losses.append(avg_train_emo_loss)
    train_sent_accs.append(train_sent_acc)
    train_emo_accs.append(train_emo_acc)

    # ---------- Validation ----------
    model.eval()
    total_val_loss, sent_val_loss_sum, emo_val_loss_sum = 0.0, 0.0, 0.0
    val_sent_preds_dict = defaultdict(list)
    val_emo_preds_dict = defaultdict(list)
    val_sent_labels_dict = {}
    val_emo_labels_dict = {}

    with torch.no_grad():
        for images, (sentiment_labels, emotion_labels, video_folder) in tqdm(val_loader, desc="Val"):
            images = images.to(device)
            sentiment_labels = sentiment_labels.to(device)
            emotion_labels = emotion_labels.to(device)

            sent_out, emo_out = model(images)
            loss_sent = sentiment_criterion(sent_out, sentiment_labels)
            loss_emo = emotion_criterion(emo_out, emotion_labels)
            loss = loss_sent + loss_emo

            total_val_loss += loss.item()
            sent_val_loss_sum += loss_sent.item()
            emo_val_loss_sum += loss_emo.item()

            pred_sent = sent_out.argmax(dim=1).cpu().numpy()
            pred_emo = emo_out.argmax(dim=1).cpu().numpy()
            sent_labels_np = sentiment_labels.cpu().numpy()
            emo_labels_np = emotion_labels.cpu().numpy()

            for i, vid in enumerate(video_folder):
                val_sent_preds_dict[vid].append(pred_sent[i])
                val_emo_preds_dict[vid].append(pred_emo[i])
                val_sent_labels_dict[vid] = sent_labels_np[i]
                val_emo_labels_dict[vid] = emo_labels_np[i]

    # Aggregate video-wise predictions
    agg_sent_preds = aggregate_predictions(val_sent_preds_dict)
    agg_emo_preds = aggregate_predictions(val_emo_preds_dict)

    agg_sent_labels = [val_sent_labels_dict[vid] for vid in agg_sent_preds]
    agg_emo_labels = [val_emo_labels_dict[vid] for vid in agg_emo_preds]
    agg_sent_preds_list = [agg_sent_preds[vid] for vid in agg_sent_preds]
    agg_emo_preds_list = [agg_emo_preds[vid] for vid in agg_emo_preds]

    avg_val_loss = total_val_loss / len(val_loader)
    avg_val_sent_loss = sent_val_loss_sum / len(val_loader)
    avg_val_emo_loss = emo_val_loss_sum / len(val_loader)
    val_sent_acc = accuracy_score(agg_sent_labels, agg_sent_preds_list)
    val_emo_acc = accuracy_score(agg_emo_labels, agg_emo_preds_list)

    val_losses.append(avg_val_loss)
    val_sent_losses.append(avg_val_sent_loss)
    val_emo_losses.append(avg_val_emo_loss)
    val_sent_accs.append(val_sent_acc)
    val_emo_accs.append(val_emo_acc)

    # ---------- Early Stopping ----------
    if avg_val_loss + min_delta < best_val_loss:
        best_val_loss = avg_val_loss
        epochs_without_improvement = 0
        torch.save(model.state_dict(), 'Adam_weights.pth')
        print(f"[INFO] Model saved.")
    else:
        epochs_without_improvement += 1
        if epochs_without_improvement >= patience:
            print(f"[EARLY STOPPING] No improvement for {patience} epochs.")
            break

    # ---------- Logging ----------
    print(f"Train Loss: {avg_train_loss:.4f} | Sent Loss: {avg_train_sent_loss:.4f} | Emo Loss: {avg_train_emo_loss:.4f}")
    print(f"Val Loss:   {avg_val_loss:.4f} | Sent Loss: {avg_val_sent_loss:.4f} | Emo Loss: {avg_val_emo_loss:.4f}")
    print(f"Sentiment Acc: Train={train_sent_acc:.4f}, Val={val_sent_acc:.4f}")
    print(f"Emotion Acc:   Train={train_emo_acc:.4f}, Val={val_emo_acc:.4f}")
# Out:
# ===== Epoch 1/50 =====
# Train: 100%|██████████| 313/313 [00:20<00:00, 14.92it/s]
# Val: 100%|██████████| 277/277 [00:01<00:00, 144.95it/s]
# [INFO] Model saved.
# Train Loss: 0.5404 | Sent Loss: 0.2475 | Emo Loss: 0.2929
# Val Loss:   5.5576 | Sent Loss: 2.2124 | Emo Loss: 3.3452
# Sentiment Acc: Train=0.9134, Val=0.3709
# Emotion Acc:   Train=0.9050, Val=0.3222
#
# ===== Epoch 2/50 =====
# Train: 100%|██████████| 313/313 [00:20<00:00, 15.05it/s]
# Val: 100%|██████████| 277/277 [00:01<00:00, 144.58it/s]
# [INFO] Model saved.
# Train Loss: 0.5599 | Sent Loss: 0.2554 | Emo Loss: 0.3044
# Val Loss:   5.4258 | Sent Loss: 2.1628 | Emo Loss: 3.2630
# Sentiment Acc: Train=0.9078, Val=0.3529
# Emotion Acc:   Train=0.8990, Val=0.3258
#
# ===== Epoch 3/50 =====
# Train: 100%|██████████| 313/313 [00:20<00:00, 14.93it/s]
# Val: 100%|██████████| 277/277 [00:01<00:00, 144.95it/s]
# Train Loss: 0.4982 | Sent Loss: 0.2290 | Emo Loss: 0.2691
# Val Loss:   5.7065 | Sent Loss: 2.2521 | Emo Loss: 3.4544
# Sentiment Acc: Train=0.9185, Val=0.3655
# Emotion Acc:   Train=0.9151, Val=0.3276
#
# ===== Epoch 4/50 =====
# Train: 100%|██████████| 313/313 [00:20<00:00, 15.00it/s]
# Val: 100%|██████████| 277/277 [00:01<00:00, 145.23it/s]
# Train Loss: 0.4844 | Sent Loss: 0.2212 | Emo Loss: 0.2632
# Val Loss:   5.7971 | Sent Loss: 2.3096 | Emo Loss: 3.4876
# Sentiment Acc: Train=0.9234, Val=0.3755
# Emotion Acc:   Train=0.9165, Val=0.3357
#
# ===== Epoch 5/50 =====
# Train: 100%|██████████| 313/313 [00:20<00:00, 15.19it/s]
# Val: 100%|██████████| 277/277 [00:01<00:00, 149.29it/s]
# Train Loss: 0.4871 | Sent Loss: 0.2181 | Emo Loss: 0.2689
# Val Loss:   5.5826 | Sent Loss: 2.2406 | Emo Loss: 3.3420
# Sentiment Acc: Train=0.9235, Val=0.3493
# Emotion Acc:   Train=0.9136, Val=0.3114
#
# ===== Epoch 6/50 =====
# Train: 100%|██████████| 313/313 [00:20<00:00, 15.16it/s]
# Val: 100%|██████████| 277/277 [00:01<00:00, 151.94it/s]
# Train Loss: 0.4381 | Sent Loss: 0.2016 | Emo Loss: 0.2365
# Val Loss:   6.3481 | Sent Loss: 2.6118 | Emo Loss: 3.7364
# Sentiment Acc: Train=0.9347, Val=0.3628
# Emotion Acc:   Train=0.9258, Val=0.3204
#
# ===== Epoch 7/50 =====
# Train: 100%|██████████| 313/313 [00:20<00:00, 15.27it/s]
# Val: 100%|██████████| 277/277 [00:01<00:00, 147.76it/s]
# [EARLY STOPPING] No improvement for 5 epochs.

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(train_sent_accs) + 1)
plt.figure(figsize=(10, 4))

# Sentiment accuracy
plt.subplot(1, 2, 1)
plt.plot(epochs, train_sent_accs, label="Train Sentiment", marker='o')
plt.plot(epochs, val_sent_accs, label="Val Sentiment", marker='o')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Sentiment Accuracy")
plt.legend()
plt.grid()

# Emotion accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs, train_emo_accs, label="Train Emotion", marker='o')
plt.plot(epochs, val_emo_accs, label="Val Emotion", marker='o')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Emotion Accuracy")
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(train_losses) + 1)

plt.figure(figsize=(10, 4))

# Sentiment loss
plt.subplot(1, 2, 1)
plt.plot(epochs, train_sent_losses, label="Train Sentiment Loss", marker='o')
plt.plot(epochs, val_sent_losses, label="Val Sentiment Loss", marker='o')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Sentiment Loss")
plt.legend()
plt.grid()

# Emotion loss
plt.subplot(1, 2, 2)
plt.plot(epochs, train_emo_losses, label="Train Emotion Loss", marker='o')
plt.plot(epochs, val_emo_losses, label="Val Emotion Loss", marker='o')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Emotion Loss")
plt.legend()
plt.grid()

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# %%
import torch.nn.functional as F
import numpy as np
from collections import defaultdict
from sklearn.metrics import classification_report

model.eval()

video_sent_logits = defaultdict(list)
video_emo_logits = defaultdict(list)
video_sent_labels = {}
video_emo_labels = {}

with torch.no_grad():
    for images, (sentiment_labels, emotion_labels, video_folder) in test_loader:
        images = images.to(device)
        sentiment_labels = sentiment_labels.to(device)
        emotion_labels = emotion_labels.to(device)

        sent_out, emo_out = model(images)

        for idx, video in enumerate(video_folder):
            video_sent_logits[video].append(sent_out[idx].cpu())
            video_emo_logits[video].append(emo_out[idx].cpu())

            if video not in video_sent_labels:
                video_sent_labels[video] = sentiment_labels[idx].item()
                video_emo_labels[video] = emotion_labels[idx].item()

# Final containers
test_sent_preds, test_sent_labels = [], []
test_emo_preds, test_emo_labels = [], []
sent_probs, emo_probs = [], []

for video in video_sent_logits:
    sent_logit_stack = torch.stack(video_sent_logits[video])
    emo_logit_stack = torch.stack(video_emo_logits[video])

    avg_sent_probs = F.softmax(sent_logit_stack, dim=1).mean(dim=0)
    avg_emo_probs = F.softmax(emo_logit_stack, dim=1).mean(dim=0)

    sent_probs.append(avg_sent_probs.numpy())
    emo_probs.append(avg_emo_probs.numpy())

    test_sent_preds.append(torch.argmax(avg_sent_probs).item())
    test_emo_preds.append(torch.argmax(avg_emo_probs).item())

    test_sent_labels.append(video_sent_labels[video])
    test_emo_labels.append(video_emo_labels[video])

print("\nSentiment Classification Report:\n", classification_report(test_sent_labels, test_sent_preds))
print("\nEmotion Classification Report:\n", classification_report(test_emo_labels, test_emo_preds))
# Out:
# Sentiment Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.48      0.68      0.57       771
#            1       0.27      0.17      0.21       330
#            2       0.36      0.23      0.28       494
#
#     accuracy                           0.43      1595
#    macro avg       0.37      0.36      0.35      1595
# weighted avg       0.40      0.43      0.40      1595
#
#
# Emotion Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.49      0.72      0.58       771
#            1       0.15      0.08      0.10       214
#            2       0.00      0.00      0.00        35
#            3       0.06      0.03      0.03       118
#            4       0.19      0.13      0.15       260
#            5       0.18      0.10      0.13       167
#            6       0.00      0.00      0.00        30
#
#     accuracy                           0.39      1595
#    macro avg       0.15      0.15      0.14      1595
# weighted avg       0.31      0.39      0.34      1595

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, confusion_matrix, precision_recall_curve

# Sentiment scores
sent_accuracy = accuracy_score(test_sent_labels, test_sent_preds)
sent_precision = precision_score(test_sent_labels, test_sent_preds, average='weighted')
sent_recall = recall_score(test_sent_labels, test_sent_preds, average='weighted')
sent_f1 = f1_score(test_sent_labels, test_sent_preds, average='weighted')
sent_conf_matrix = confusion_matrix(test_sent_labels, test_sent_preds)

# Emotion scores
emo_accuracy = accuracy_score(test_emo_labels, test_emo_preds)
emo_precision = precision_score(test_emo_labels, test_emo_preds, average='weighted')
emo_recall = recall_score(test_emo_labels, test_emo_preds, average='weighted')
emo_f1 = f1_score(test_emo_labels, test_emo_preds, average='weighted')
emo_conf_matrix = confusion_matrix(test_emo_labels, test_emo_preds)

# Print
print("\n Sentiment Metrics")
print(f"Accuracy:  {sent_accuracy:.4f}")
print(f"Precision: {sent_precision:.4f}")
print(f"Recall:    {sent_recall:.4f}")
print(f"F1 Score:  {sent_f1:.4f}")

print("\n Emotion Metrics")
print(f"Accuracy:  {emo_accuracy:.4f}")
print(f"Precision: {emo_precision:.4f}")
print(f"Recall:    {emo_recall:.4f}")
print(f"F1 Score:  {emo_f1:.4f}")
# Out:
#  Sentiment Metrics
# Accuracy:  0.4006
# Precision: 0.3668
# Recall:    0.4006
# F1 Score:  0.3736
#
#  Emotion Metrics
# Accuracy:  0.3580
# Precision: 0.2758
# Recall:    0.3580
# F1 Score:  0.3049

# %%
from sklearn.preprocessing import label_binarize
from sklearn.metrics import (
    roc_curve, auc, precision_recall_curve, average_precision_score,
    confusion_matrix, ConfusionMatrixDisplay
)
import matplotlib.pyplot as plt
import numpy as np

# Convert to NumPy arrays
test_sent_labels = np.array(test_sent_labels)
test_emo_labels = np.array(test_emo_labels)
sent_probs = np.vstack(sent_probs)  # (N, num_classes)
emo_probs = np.vstack(emo_probs)

n_sent_classes = sent_probs.shape[1]
n_emo_classes = emo_probs.shape[1]

test_sent_labels_bin = label_binarize(test_sent_labels, classes=range(n_sent_classes))
test_emo_labels_bin = label_binarize(test_emo_labels, classes=range(n_emo_classes))

def plot_multiclass_roc(true_bin, probs, n_classes, title):
    plt.figure()
    for i in range(n_classes):
        fpr, tpr, _ = roc_curve(true_bin[:, i], probs[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f'Class {i} (AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.title(f'{title} ROC Curve')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    plt.grid(True)
    plt.show()

def plot_multiclass_prc(true_bin, probs, n_classes, title):
    plt.figure()
    for i in range(n_classes):
        precision, recall, _ = precision_recall_curve(true_bin[:, i], probs[:, i])
        pr_auc = average_precision_score(true_bin[:, i], probs[:, i])
        plt.plot(recall, precision, label=f'Class {i} (AUC = {pr_auc:.2f})')
    plt.title(f'{title} Precision-Recall Curve')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.legend()
    plt.grid(True)
    plt.show()

def plot_conf_matrix(true_labels, preds, title):
    labels = sorted(set(true_labels) | set(preds))
    cm = confusion_matrix(true_labels, preds, labels=labels)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
    disp.plot(cmap='Blues', values_format='d')
    plt.title(f'{title} Confusion Matrix')
    plt.grid(False)
    plt.show()

# ---- Plotting ----
plot_multiclass_roc(test_sent_labels_bin, sent_probs, n_sent_classes, 'Sentiment')
plot_multiclass_prc(test_sent_labels_bin, sent_probs, n_sent_classes, 'Sentiment')
plot_conf_matrix(test_sent_labels, test_sent_preds, 'Sentiment')

plot_multiclass_roc(test_emo_labels_bin, emo_probs, n_emo_classes, 'Emotion')
plot_multiclass_prc(test_emo_labels_bin, emo_probs, n_emo_classes, 'Emotion')
plot_conf_matrix(test_emo_labels, test_emo_preds, 'Emotion')
